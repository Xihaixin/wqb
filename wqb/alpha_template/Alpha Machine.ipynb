# %% [markdown]
# ## 1, Import Library

# %%
from wqb.machine_lib import *

# %% [markdown]
# ## 2, 登录
# <div style="margin-left: 20px;">
# 1, 在machine_lib文件的login方法中填写用户名和密码后保存，然后来到本文件Restart Kernal后重新import machine_lib后才在本文件生效
# </div>
#
# <div style="margin-left: 20px;">
# 2, 打印INVALID_CREDENTAIL即登录失败，打印自己的user_id信息才是登录成功。
# </div>

# %%
s = login()
# Out:
# b'{"user":{"id":"HS29282"},"token":{"expiry":14400.0},"permissions":["BEFORE_AND_AFTER_PERFORMANCE_V2","BRAIN_LABS","BRAIN_LABS_JUPYTER_LAB","CONSULTANT","MULTI_SIMULATION","PROD_ALPHAS","REFERRAL","SUPER_ALPHA","VISUALIZATION","WORKDAY"]}'

# %% [markdown]
# ## 3, 获取数据字段
# <div style="margin-left: 20px;">
# 在官网Data页面中显示的为自己目前有权限的数据集，在数据集Description面板下可以看到dataset_id
# </div>

# %%
df = get_datafields(s, dataset_id = 'analyst4', region='USA', universe='TOP3000', delay=1)
df
# Out:
#                                             id  \
# 0    actual_cashflow_per_share_value_quarterly
# 1              actual_dividend_value_quarterly
# 2                   actual_eps_value_quarterly
# 3                    actual_sales_value_annual
# 4                 actual_sales_value_quarterly
# ..                                         ...
# 648                        total_assets_amount
# 649                total_assets_reported_value
# 650                total_goodwill_actual_value
# 651                      total_goodwill_amount
# 652              total_goodwill_reported_value
#
#                                            description  \
# 0    Cash Flow Per Share - actual value for the qua...
# 1              Dividend - Actual value for the quarter
# 2    Earnings Per Share (Income Statement/Per Share...
# 3                                 Sales - Actual Value
# 4    Sales - Value in financial services income sta...
# ..                                                 ...
# 648                        Total Assets - actual value
# 649                        Total Assets - actual value
# 650         Total Goodwill - announced financial value
# 651                             Total Goodwill - Value
# 652          Total Goodwill - Actual Value in Millions
#
#                                                dataset  \
# 0    {'id': 'analyst4', 'name': 'Analyst Estimate D...
# 1    {'id': 'analyst4', 'name': 'Analyst Estimate D...
# 2    {'id': 'analyst4', 'name': 'Analyst Estimate D...
# 3    {'id': 'analyst4', 'name': 'Analyst Estimate D...
# 4    {'id': 'analyst4', 'name': 'Analyst Estimate D...
# ..                                                 ...
# 648  {'id': 'analyst4', 'name': 'Analyst Estimate D...
# 649  {'id': 'analyst4', 'name': 'Analyst Estimate D...
# 650  {'id': 'analyst4', 'name': 'Analyst Estimate D...
# 651  {'id': 'analyst4', 'name': 'Analyst Estimate D...
# 652  {'id': 'analyst4', 'name': 'Analyst Estimate D...
#
#                                  category  \
# 0    {'id': 'analyst', 'name': 'Analyst'}
# 1    {'id': 'analyst', 'name': 'Analyst'}
# 2    {'id': 'analyst', 'name': 'Analyst'}
# 3    {'id': 'analyst', 'name': 'Analyst'}
# 4    {'id': 'analyst', 'name': 'Analyst'}
# ..                                    ...
# 648  {'id': 'analyst', 'name': 'Analyst'}
# 649  {'id': 'analyst', 'name': 'Analyst'}
# 650  {'id': 'analyst', 'name': 'Analyst'}
# 651  {'id': 'analyst', 'name': 'Analyst'}
# 652  {'id': 'analyst', 'name': 'Analyst'}
#
#                                            subcategory region  delay universe  \
# 0    {'id': 'analyst-analyst-estimates', 'name': 'A...    USA      1  TOP3000
# 1    {'id': 'analyst-analyst-estimates', 'name': 'A...    USA      1  TOP3000
# 2    {'id': 'analyst-analyst-estimates', 'name': 'A...    USA      1  TOP3000
# 3    {'id': 'analyst-analyst-estimates', 'name': 'A...    USA      1  TOP3000
# 4    {'id': 'analyst-analyst-estimates', 'name': 'A...    USA      1  TOP3000
# ..                                                 ...    ...    ...      ...
# 648  {'id': 'analyst-analyst-estimates', 'name': 'A...    USA      1  TOP3000
# 649  {'id': 'analyst-analyst-estimates', 'name': 'A...    USA      1  TOP3000
# 650  {'id': 'analyst-analyst-estimates', 'name': 'A...    USA      1  TOP3000
# 651  {'id': 'analyst-analyst-estimates', 'name': 'A...    USA      1  TOP3000
# 652  {'id': 'analyst-analyst-estimates', 'name': 'A...    USA      1  TOP3000
#
#        type  coverage  userCount  alphaCount  pyramidMultiplier themes
# 0    MATRIX    0.4684          0           0                1.2     []
# 1    MATRIX    0.6120          0           0                1.2     []
# 2    MATRIX    1.0000          0           0                1.2     []
# 3    MATRIX    0.9943          0           0                1.2     []
# 4    MATRIX    1.0000          0           0                1.2     []
# ..      ...       ...        ...         ...                ...    ...
# 648  MATRIX    0.8035          0           0                1.2     []
# 649  MATRIX    0.6486          0           0                1.2     []
# 650  MATRIX    0.3761          0           0                1.2     []
# 651  MATRIX    0.5285          0           0                1.2     []
# 652  MATRIX    0.3761          0           0                1.2     []
#
# [653 rows x 14 columns]

# %% [markdown]
# ## 4，数据字段预处理
#
# <div style="margin-left: 20px;">
# 1, matrix, vector 数据类型
# </div>
#
# <div style="margin-left: 20px;">
# 2, ts_backfill 回填缺失值，提高数据Coverage
# </div>
#
# <div style="margin-left: 20px;">
# 2, winsorize 去极值
# </div>

# %%
pc_fields = process_datafields(df)
len(pc_fields)
pc_fields
# Out:
# ['winsorize(ts_backfill(actual_cashflow_per_share_value_quarterly, 120), std=4)',
#  'winsorize(ts_backfill(actual_dividend_value_quarterly, 120), std=4)',
#  'winsorize(ts_backfill(actual_eps_value_quarterly, 120), std=4)',
#  'winsorize(ts_backfill(actual_sales_value_annual, 120), std=4)',
#  'winsorize(ts_backfill(actual_sales_value_quarterly, 120), std=4)',
#  'winsorize(ts_backfill(actuals_value_currency_code, 120), std=4)',
#  'winsorize(ts_backfill(anl4_adjusted_netincome_ft, 120), std=4)',
#  'winsorize(ts_backfill(anl4_af_cfps_value, 120), std=4)',
#  'winsorize(ts_backfill(anl4_af_div_value, 120), std=4)',
#  'winsorize(ts_backfill(anl4_af_eps_value, 120), std=4)',
#  'winsorize(ts_backfill(anl4_afv4_cfps_high, 120), std=4)',
#  'winsorize(ts_backfill(anl4_afv4_cfps_low, 120), std=4)',
#  'winsorize(ts_backfill(anl4_afv4_cfps_mean, 120), std=4)',
#  'winsorize(ts_backfill(anl4_afv4_cfps_median, 120), std=4)',
#  'winsorize(ts_backfill(anl4_afv4_cfps_number, 120), std=4)',
#  'winsorize(ts_backfill(anl4_afv4_div_high, 120), std=4)',
#  'winsorize(ts_backfill(anl4_afv4_div_low, 120), std=4)',
#  'winsorize(ts_backfill(anl4_afv4_div_mean, 120), std=4)',
#  'winsorize(ts_backfill(anl4_afv4_div_median, 120), std=4)',
#  'winsorize(ts_backfill(anl4_afv4_div_number, 120), std=4)',
#  'winsorize(ts_backfill(anl4_afv4_div_std, 120), std=4)',
#  'winsorize(ts_backfill(anl4_afv4_dts_spe, 120), std=4)',
#  'winsorize(ts_backfill(anl4_afv4_eps_high, 120), std=4)',
#  'winsorize(ts_backfill(anl4_afv4_eps_low, 120), std=4)',
#  'winsorize(ts_backfill(anl4_afv4_eps_mean, 120), std=4)',
#  'winsorize(ts_backfill(anl4_afv4_eps_number, 120), std=4)',
#  'winsorize(ts_backfill(anl4_afv4_median_eps, 120), std=4)',
#  'winsorize(ts_backfill(anl4_bvps_flag, 120), std=4)',
#  'winsorize(ts_backfill(anl4_bvps_high, 120), std=4)',
#  'winsorize(ts_backfill(anl4_bvps_low, 120), std=4)',
#  'winsorize(ts_backfill(anl4_bvps_mean, 120), std=4)',
#  'winsorize(ts_backfill(anl4_bvps_median, 120), std=4)',
#  'winsorize(ts_backfill(anl4_bvps_number, 120), std=4)',
#  'winsorize(ts_backfill(anl4_bvps_value, 120), std=4)',
#  'winsorize(ts_backfill(anl4_capex_flag, 120), std=4)',
#  'winsorize(ts_backfill(anl4_capex_high, 120), std=4)',
#  'winsorize(ts_backfill(anl4_capex_low, 120), std=4)',
#  'winsorize(ts_backfill(anl4_capex_mean, 120), std=4)',
#  'winsorize(ts_backfill(anl4_capex_number, 120), std=4)',
#  'winsorize(ts_backfill(anl4_capex_std, 120), std=4)',
#  'winsorize(ts_backfill(anl4_capex_value, 120), std=4)',
#  'winsorize(ts_backfill(anl4_cff_flag, 120), std=4)',
#  'winsorize(ts_backfill(anl4_cff_high, 120), std=4)',
#  'winsorize(ts_backfill(anl4_cff_low, 120), std=4)',
#  'winsorize(ts_backfill(anl4_cff_mean, 120), std=4)',
#  'winsorize(ts_backfill(anl4_cff_median, 120), std=4)',
#  'winsorize(ts_backfill(anl4_cff_number, 120), std=4)',
#  'winsorize(ts_backfill(anl4_cff_value, 120), std=4)',
#  'winsorize(ts_backfill(anl4_cfi_flag, 120), std=4)',
#  'winsorize(ts_backfill(anl4_cfi_high, 120), std=4)',
#  'winsorize(ts_backfill(anl4_cfi_low, 120), std=4)',
#  'winsorize(ts_backfill(anl4_cfi_mean, 120), std=4)',
#  'winsorize(ts_backfill(anl4_cfi_median, 120), std=4)',
#  'winsorize(ts_backfill(anl4_cfi_number, 120), std=4)',
#  'winsorize(ts_backfill(anl4_cfi_value, 120), std=4)',
#  'winsorize(ts_backfill(anl4_cfo_flag, 120), std=4)',
#  'winsorize(ts_backfill(anl4_cfo_high, 120), std=4)',
#  'winsorize(ts_backfill(anl4_cfo_low, 120), std=4)',
#  'winsorize(ts_backfill(anl4_cfo_mean, 120), std=4)',
#  'winsorize(ts_backfill(anl4_cfo_median, 120), std=4)',
#  'winsorize(ts_backfill(anl4_cfo_number, 120), std=4)',
#  'winsorize(ts_backfill(anl4_cfo_value, 120), std=4)',
#  'winsorize(ts_backfill(anl4_dts_ptp, 120), std=4)',
#  'winsorize(ts_backfill(anl4_dts_rspe, 120), std=4)',
#  'winsorize(ts_backfill(anl4_ebit_high, 120), std=4)',
#  'winsorize(ts_backfill(anl4_ebit_low, 120), std=4)',
#  'winsorize(ts_backfill(anl4_ebit_mean, 120), std=4)',
#  'winsorize(ts_backfill(anl4_ebit_median, 120), std=4)',
#  'winsorize(ts_backfill(anl4_ebit_number, 120), std=4)',
#  'winsorize(ts_backfill(anl4_ebit_std, 120), std=4)',
#  'winsorize(ts_backfill(anl4_ebit_value, 120), std=4)',
#  'winsorize(ts_backfill(anl4_ebitda_flag, 120), std=4)',
#  'winsorize(ts_backfill(anl4_ebitda_high, 120), std=4)',
#  'winsorize(ts_backfill(anl4_ebitda_low, 120), std=4)',
#  'winsorize(ts_backfill(anl4_ebitda_mean, 120), std=4)',
#  'winsorize(ts_backfill(anl4_ebitda_number, 120), std=4)',
#  'winsorize(ts_backfill(anl4_ebitda_std, 120), std=4)',
#  'winsorize(ts_backfill(anl4_ebitda_value, 120), std=4)',
#  'winsorize(ts_backfill(anl4_epsa_flag, 120), std=4)',
#  'winsorize(ts_backfill(anl4_epsr_flag, 120), std=4)',
#  'winsorize(ts_backfill(anl4_epsr_high, 120), std=4)',
#  'winsorize(ts_backfill(anl4_epsr_low, 120), std=4)',
#  'winsorize(ts_backfill(anl4_epsr_mean, 120), std=4)',
#  'winsorize(ts_backfill(anl4_epsr_number, 120), std=4)',
#  'winsorize(ts_backfill(anl4_epsr_value, 120), std=4)',
#  'winsorize(ts_backfill(anl4_fcf_flag, 120), std=4)',
#  'winsorize(ts_backfill(anl4_fcf_high, 120), std=4)',
#  'winsorize(ts_backfill(anl4_fcf_low, 120), std=4)',
#  'winsorize(ts_backfill(anl4_fcf_mean, 120), std=4)',
#  'winsorize(ts_backfill(anl4_fcf_median, 120), std=4)',
#  'winsorize(ts_backfill(anl4_fcf_number, 120), std=4)',
#  'winsorize(ts_backfill(anl4_fcf_value, 120), std=4)',
#  'winsorize(ts_backfill(anl4_fcfps_flag, 120), std=4)',
#  'winsorize(ts_backfill(anl4_fcfps_high, 120), std=4)',
#  'winsorize(ts_backfill(anl4_fcfps_low, 120), std=4)',
#  'winsorize(ts_backfill(anl4_fcfps_mean, 120), std=4)',
#  'winsorize(ts_backfill(anl4_fcfps_median, 120), std=4)',
#  'winsorize(ts_backfill(anl4_fcfps_number, 120), std=4)',
#  'winsorize(ts_backfill(anl4_ffo_flag, 120), std=4)',
#  'winsorize(ts_backfill(anl4_flag_erbfintax, 120), std=4)',
#  'winsorize(ts_backfill(anl4_gric_flag, 120), std=4)',
#  'winsorize(ts_backfill(anl4_gric_high, 120), std=4)',
#  'winsorize(ts_backfill(anl4_gric_low, 120), std=4)',
#  'winsorize(ts_backfill(anl4_gric_mean, 120), std=4)',
#  'winsorize(ts_backfill(anl4_gric_median, 120), std=4)',
#  'winsorize(ts_backfill(anl4_gric_number, 120), std=4)',
#  'winsorize(ts_backfill(anl4_gric_std, 120), std=4)',
#  'winsorize(ts_backfill(anl4_gric_value, 120), std=4)',
#  'winsorize(ts_backfill(anl4_median_capexp, 120), std=4)',
#  'winsorize(ts_backfill(anl4_median_epsreported, 120), std=4)',
#  'winsorize(ts_backfill(anl4_medianepsbfam, 120), std=4)',
#  'winsorize(ts_backfill(anl4_netdebt_flag, 120), std=4)',
#  'winsorize(ts_backfill(anl4_netdebt_high, 120), std=4)',
#  'winsorize(ts_backfill(anl4_netdebt_low, 120), std=4)',
#  'winsorize(ts_backfill(anl4_netdebt_mean, 120), std=4)',
#  'winsorize(ts_backfill(anl4_netdebt_median, 120), std=4)',
#  'winsorize(ts_backfill(anl4_netdebt_number, 120), std=4)',
#  'winsorize(ts_backfill(anl4_netprofit_flag, 120), std=4)',
#  'winsorize(ts_backfill(anl4_netprofit_high, 120), std=4)',
#  'winsorize(ts_backfill(anl4_netprofit_low, 120), std=4)',
#  'winsorize(ts_backfill(anl4_netprofit_mean, 120), std=4)',
#  'winsorize(ts_backfill(anl4_netprofit_median, 120), std=4)',
#  'winsorize(ts_backfill(anl4_netprofit_number, 120), std=4)',
#  'winsorize(ts_backfill(anl4_netprofit_std, 120), std=4)',
#  'winsorize(ts_backfill(anl4_netprofit_value, 120), std=4)',
#  'winsorize(ts_backfill(anl4_netprofita_high, 120), std=4)',
#  'winsorize(ts_backfill(anl4_netprofita_low, 120), std=4)',
#  'winsorize(ts_backfill(anl4_netprofita_mean, 120), std=4)',
#  'winsorize(ts_backfill(anl4_netprofita_median, 120), std=4)',
#  'winsorize(ts_backfill(anl4_netprofita_number, 120), std=4)',
#  'winsorize(ts_backfill(anl4_netprofita_std, 120), std=4)',
#  'winsorize(ts_backfill(anl4_netprofita_value, 120), std=4)',
#  'winsorize(ts_backfill(anl4_ptp_flag, 120), std=4)',
#  'winsorize(ts_backfill(anl4_ptp_high, 120), std=4)',
#  'winsorize(ts_backfill(anl4_ptp_low, 120), std=4)',
#  'winsorize(ts_backfill(anl4_ptp_mean, 120), std=4)',
#  'winsorize(ts_backfill(anl4_ptp_median, 120), std=4)',
#  'winsorize(ts_backfill(anl4_ptp_number, 120), std=4)',
#  'winsorize(ts_backfill(anl4_ptp_value, 120), std=4)',
#  'winsorize(ts_backfill(anl4_ptpr_flag, 120), std=4)',
#  'winsorize(ts_backfill(anl4_ptpr_high, 120), std=4)',
#  'winsorize(ts_backfill(anl4_ptpr_low, 120), std=4)',
#  'winsorize(ts_backfill(anl4_ptpr_mean, 120), std=4)',
#  'winsorize(ts_backfill(anl4_ptpr_median, 120), std=4)',
#  'winsorize(ts_backfill(anl4_ptpr_number, 120), std=4)',
#  'winsorize(ts_backfill(anl4_qf_az_cfps_mean, 120), std=4)',
#  'winsorize(ts_backfill(anl4_qf_az_cfps_median, 120), std=4)',
#  'winsorize(ts_backfill(anl4_qf_az_cfps_number, 120), std=4)',
#  'winsorize(ts_backfill(anl4_qf_az_div_mean, 120), std=4)',
#  'winsorize(ts_backfill(anl4_qf_az_div_median, 120), std=4)',
#  'winsorize(ts_backfill(anl4_qf_az_div_number, 120), std=4)',
#  'winsorize(ts_backfill(anl4_qf_az_dts_spe, 120), std=4)',
#  'winsorize(ts_backfill(anl4_qf_az_eps, 120), std=4)',
#  'winsorize(ts_backfill(anl4_qf_az_eps_mean, 120), std=4)',
#  'winsorize(ts_backfill(anl4_qf_az_eps_number, 120), std=4)',
#  'winsorize(ts_backfill(anl4_qf_az_hgih_spe, 120), std=4)',
#  'winsorize(ts_backfill(anl4_qf_az_hgih_spfc, 120), std=4)',
#  'winsorize(ts_backfill(anl4_qf_az_hgih_vid, 120), std=4)',
#  'winsorize(ts_backfill(anl4_qf_az_wol_spe, 120), std=4)',
#  'winsorize(ts_backfill(anl4_qf_az_wol_spfc, 120), std=4)',
#  'winsorize(ts_backfill(anl4_qf_az_wol_vid, 120), std=4)',
#  'winsorize(ts_backfill(anl4_qfd1_az_cfps_median, 120), std=4)',
#  'winsorize(ts_backfill(anl4_qfd1_az_cfps_number, 120), std=4)',
#  'winsorize(ts_backfill(anl4_qfd1_az_div_median, 120), std=4)',
#  'winsorize(ts_backfill(anl4_qfd1_az_div_number, 120), std=4)',
#  'winsorize(ts_backfill(anl4_qfd1_az_dts_spe, 120), std=4)',
#  'winsorize(ts_backfill(anl4_qfd1_az_eps_number, 120), std=4)',
#  'winsorize(ts_backfill(anl4_qfd1_az_hgih_spe, 120), std=4)',
#  'winsorize(ts_backfill(anl4_qfd1_az_hgih_spfc, 120), std=4)',
#  'winsorize(ts_backfill(anl4_qfd1_az_hgih_vid, 120), std=4)',
#  'winsorize(ts_backfill(anl4_qfd1_az_wol_spe, 120), std=4)',
#  'winsorize(ts_backfill(anl4_qfd1_az_wol_spfc, 120), std=4)',
#  'winsorize(ts_backfill(anl4_qfd1_az_wol_vid, 120), std=4)',
#  'winsorize(ts_backfill(anl4_qfd1_azeps, 120), std=4)',
#  'winsorize(ts_backfill(anl4_qfv4_cfps_high, 120), std=4)',
#  'winsorize(ts_backfill(anl4_qfv4_cfps_low, 120), std=4)',
#  'winsorize(ts_backfill(anl4_qfv4_cfps_mean, 120), std=4)',
#  'winsorize(ts_backfill(anl4_qfv4_cfps_median, 120), std=4)',
#  'winsorize(ts_backfill(anl4_qfv4_cfps_number, 120), std=4)',
#  'winsorize(ts_backfill(anl4_qfv4_div_high, 120), std=4)',
#  'winsorize(ts_backfill(anl4_qfv4_div_low, 120), std=4)',
#  'winsorize(ts_backfill(anl4_qfv4_div_mean, 120), std=4)',
#  'winsorize(ts_backfill(anl4_qfv4_div_median, 120), std=4)',
#  'winsorize(ts_backfill(anl4_qfv4_div_number, 120), std=4)',
#  'winsorize(ts_backfill(anl4_qfv4_dts_spe, 120), std=4)',
#  'winsorize(ts_backfill(anl4_qfv4_eps_high, 120), std=4)',
#  'winsorize(ts_backfill(anl4_qfv4_eps_low, 120), std=4)',
#  'winsorize(ts_backfill(anl4_qfv4_eps_mean, 120), std=4)',
#  'winsorize(ts_backfill(anl4_qfv4_eps_number, 120), std=4)',
#  'winsorize(ts_backfill(anl4_qfv4_median_eps, 120), std=4)',
#  'winsorize(ts_backfill(anl4_rd_exp_flag, 120), std=4)',
#  'winsorize(ts_backfill(anl4_rd_exp_high, 120), std=4)',
#  'winsorize(ts_backfill(anl4_rd_exp_low, 120), std=4)',
#  'winsorize(ts_backfill(anl4_rd_exp_mean, 120), std=4)',
#  'winsorize(ts_backfill(anl4_rd_exp_median, 120), std=4)',
#  'winsorize(ts_backfill(anl4_rd_exp_number, 120), std=4)',
#  'winsorize(ts_backfill(anl4_tbve_ft, 120), std=4)',
#  'winsorize(ts_backfill(anl4_tbvps_high, 120), std=4)',
#  'winsorize(ts_backfill(anl4_tbvps_low, 120), std=4)',
#  'winsorize(ts_backfill(anl4_tbvps_mean, 120), std=4)',
#  'winsorize(ts_backfill(anl4_tbvps_median, 120), std=4)',
#  'winsorize(ts_backfill(anl4_tbvps_number, 120), std=4)',
#  'winsorize(ts_backfill(anl4_tot_gw_ft, 120), std=4)',
#  'winsorize(ts_backfill(anl4_totassets_flag, 120), std=4)',
#  'winsorize(ts_backfill(anl4_totassets_high, 120), std=4)',
#  'winsorize(ts_backfill(anl4_totassets_low, 120), std=4)',
#  'winsorize(ts_backfill(anl4_totassets_mean, 120), std=4)',
#  'winsorize(ts_backfill(anl4_totassets_median, 120), std=4)',
#  'winsorize(ts_backfill(anl4_totassets_number, 120), std=4)',
#  'winsorize(ts_backfill(anl4_totassets_std, 120), std=4)',
#  'winsorize(ts_backfill(anl4_totassets_value, 120), std=4)',
#  'winsorize(ts_backfill(anl4_totgw_high, 120), std=4)',
#  'winsorize(ts_backfill(anl4_totgw_low, 120), std=4)',
#  'winsorize(ts_backfill(anl4_totgw_mean, 120), std=4)',
#  'winsorize(ts_backfill(anl4_totgw_median, 120), std=4)',
#  'winsorize(ts_backfill(anl4_totgw_number, 120), std=4)',
#  'winsorize(ts_backfill(basic_shares_max_guidance_qtr, 120), std=4)',
#  'winsorize(ts_backfill(book_value_per_share_2, 120), std=4)',
#  'winsorize(ts_backfill(book_value_per_share_min_guidance_qtr, 120), std=4)',
#  'winsorize(ts_backfill(book_value_per_share_reported_value, 120), std=4)',
#  'winsorize(ts_backfill(capital_expenditure_amount, 120), std=4)',
#  'winsorize(ts_backfill(capital_expenditure_guidance_value, 120), std=4)',
#  'winsorize(ts_backfill(capital_expenditure_max_guidance_qtr, 120), std=4)',
#  'winsorize(ts_backfill(capital_expenditure_reported_value, 120), std=4)',
#  'winsorize(ts_backfill(cash_flow_financing_max_guidance, 120), std=4)',
#  'winsorize(ts_backfill(cash_flow_from_financing, 120), std=4)',
#  'winsorize(ts_backfill(cash_flow_from_investing, 120), std=4)',
#  'winsorize(ts_backfill(cash_flow_from_operations, 120), std=4)',
#  'winsorize(ts_backfill(cash_flow_operations_min_guidance, 120), std=4)',
#  'winsorize(ts_backfill(cashflow_per_share_average, 120), std=4)',
#  'winsorize(ts_backfill(cashflow_per_share_estimate_count, 120), std=4)',
#  'winsorize(ts_backfill(cashflow_per_share_max_guidance, 120), std=4)',
#  'winsorize(ts_backfill(cashflow_per_share_max_guidance_quarterly, 120), std=4)',
#  'winsorize(ts_backfill(cashflow_per_share_maximum, 120), std=4)',
#  'winsorize(ts_backfill(cashflow_per_share_median_value, 120), std=4)',
#  'winsorize(ts_backfill(cashflow_per_share_min_guidance, 120), std=4)',
#  'winsorize(ts_backfill(cashflow_per_share_min_guidance_quarterly, 120), std=4)',
#  'winsorize(ts_backfill(cashflow_per_share_minimum, 120), std=4)',
#  'winsorize(ts_backfill(dividend_estimate_average, 120), std=4)',
#  'winsorize(ts_backfill(dividend_estimate_count, 120), std=4)',
#  'winsorize(ts_backfill(dividend_estimate_maximum, 120), std=4)',
#  'winsorize(ts_backfill(dividend_estimate_median_value, 120), std=4)',
#  'winsorize(ts_backfill(dividend_estimate_minimum, 120), std=4)',
#  'winsorize(ts_backfill(dividend_estimate_standard_deviation, 120), std=4)',
#  'winsorize(ts_backfill(dividend_estimate_stddev_quarterly, 120), std=4)',
#  'winsorize(ts_backfill(dividend_max_guidance_quarterly, 120), std=4)',
#  'winsorize(ts_backfill(dividend_max_guidance_value, 120), std=4)',
#  'winsorize(ts_backfill(dividend_min_guidance_quarterly, 120), std=4)',
#  'winsorize(ts_backfill(dividend_min_guidance_value, 120), std=4)',
#  'winsorize(ts_backfill(earnings_per_share_average, 120), std=4)',
#  'winsorize(ts_backfill(earnings_per_share_estimate_count, 120), std=4)',
#  'winsorize(ts_backfill(earnings_per_share_guidance_value, 120), std=4)',
#  'winsorize(ts_backfill(earnings_per_share_max_guidance, 120), std=4)',
#  'winsorize(ts_backfill(earnings_per_share_maximum, 120), std=4)',
#  'winsorize(ts_backfill(earnings_per_share_median_value, 120), std=4)',
#  'winsorize(ts_backfill(earnings_per_share_min_guidance, 120), std=4)',
#  'winsorize(ts_backfill(earnings_per_share_minimum, 120), std=4)',
#  'winsorize(ts_backfill(earnings_per_share_nongaap_value, 120), std=4)',
#  'winsorize(ts_backfill(earnings_per_share_reported, 120), std=4)',
#  'winsorize(ts_backfill(earnings_per_share_reported_value, 120), std=4)',
#  'winsorize(ts_backfill(earnings_per_share_standard_deviation, 120), std=4)',
#  'winsorize(ts_backfill(ebit_reported_value, 120), std=4)',
#  'winsorize(ts_backfill(ebitda_reported_value, 120), std=4)',
#  'winsorize(ts_backfill(eps_adjusted_min_guidance_qtr, 120), std=4)',
#  'winsorize(ts_backfill(eps_adjusted_min_guidance_value, 120), std=4)',
#  'winsorize(ts_backfill(eps_guidance_value_quarterly, 120), std=4)',
#  'winsorize(ts_backfill(eps_max_guidance_quarterly, 120), std=4)',
#  'winsorize(ts_backfill(eps_min_guidance_quarterly, 120), std=4)',
#  'winsorize(ts_backfill(eps_reported_min_guidance_qtr, 120), std=4)',
#  'winsorize(ts_backfill(est_bookvalue_ps, 120), std=4)',
#  'winsorize(ts_backfill(est_capex, 120), std=4)',
#  'winsorize(ts_backfill(est_cashflow_fin, 120), std=4)',
#  'winsorize(ts_backfill(est_cashflow_invst, 120), std=4)',
#  'winsorize(ts_backfill(est_cashflow_op, 120), std=4)',
#  'winsorize(ts_backfill(est_cashflow_ps, 120), std=4)',
#  'winsorize(ts_backfill(est_dividend_ps, 120), std=4)',
#  'winsorize(ts_backfill(est_ebit, 120), std=4)',
#  'winsorize(ts_backfill(est_ebitda, 120), std=4)',
#  'winsorize(ts_backfill(est_eps, 120), std=4)',
#  'winsorize(ts_backfill(est_epsa, 120), std=4)',
#  'winsorize(ts_backfill(est_epsr, 120), std=4)',
#  'winsorize(ts_backfill(est_fcf, 120), std=4)',
#  'winsorize(ts_backfill(est_fcf_ps, 120), std=4)',
#  'winsorize(ts_backfill(est_ffo, 120), std=4)',
#  'winsorize(ts_backfill(est_grossincome, 120), std=4)',
#  'winsorize(ts_backfill(est_netdebt, 120), std=4)',
#  'winsorize(ts_backfill(est_netprofit, 120), std=4)',
#  'winsorize(ts_backfill(est_netprofit_adj, 120), std=4)',
#  'winsorize(ts_backfill(est_ptp, 120), std=4)',
#  'winsorize(ts_backfill(est_ptpr, 120), std=4)',
#  'winsorize(ts_backfill(est_rd_expense, 120), std=4)',
#  'winsorize(ts_backfill(est_sales, 120), std=4)',
#  'winsorize(ts_backfill(est_sga, 120), std=4)',
#  'winsorize(ts_backfill(est_shequity, 120), std=4)',
#  'winsorize(ts_backfill(est_tbv_ps, 120), std=4)',
#  'winsorize(ts_backfill(est_tot_assets, 120), std=4)',
#  'winsorize(ts_backfill(est_tot_goodwill, 120), std=4)',
#  'winsorize(ts_backfill(financing_cashflow_reported_value, 120), std=4)',
#  'winsorize(ts_backfill(free_cash_flow_per_share, 120), std=4)',
#  'winsorize(ts_backfill(free_cash_flow_per_share_actual_value, 120), std=4)',
#  'winsorize(ts_backfill(free_cash_flow_per_share_max_guidance, 120), std=4)',
#  'winsorize(ts_backfill(free_cash_flow_per_share_reported_value, 120), std=4)',
#  'winsorize(ts_backfill(free_cash_flow_reported_value, 120), std=4)',
#  'winsorize(ts_backfill(free_cash_flow_total, 120), std=4)',
#  'winsorize(ts_backfill(funds_from_operations_max_guidance, 120), std=4)',
#  'winsorize(ts_backfill(goodwill_min_guidance_qtr, 120), std=4)',
#  'winsorize(ts_backfill(gross_income_reported_value, 120), std=4)',
#  'winsorize(ts_backfill(gross_income_total, 120), std=4)',
#  'winsorize(ts_backfill(guidance_reporting_currency, 120), std=4)',
#  'winsorize(ts_backfill(highest_sales_estimate, 120), std=4)',
#  'winsorize(ts_backfill(investing_cashflow_reported_value, 120), std=4)',
#  'winsorize(ts_backfill(lowest_sales_estimate, 120), std=4)',
#  'winsorize(ts_backfill(max_adjusted_eps_guidance, 120), std=4)',
#  'winsorize(ts_backfill(max_adjusted_eps_guidance_2, 120), std=4)',
#  'winsorize(ts_backfill(max_adjusted_funds_from_operations_adj_guidance, 120), std=4)',
#  'winsorize(ts_backfill(max_adjusted_funds_from_operations_guidance, 120), std=4)',
#  'winsorize(ts_backfill(max_adjusted_funds_from_operations_guidance_2, 120), std=4)',
#  'winsorize(ts_backfill(max_adjusted_net_income_guidance, 120), std=4)',
#  'winsorize(ts_backfill(max_adjusted_net_profit_guidance, 120), std=4)',
#  'winsorize(ts_backfill(max_book_value_per_share_guidance, 120), std=4)',
#  'winsorize(ts_backfill(max_book_value_per_share_guidance_2, 120), std=4)',
#  'winsorize(ts_backfill(max_capital_expenditure_guidance, 120), std=4)',
#  'winsorize(ts_backfill(max_custom_eps_guidance, 120), std=4)',
#  'winsorize(ts_backfill(max_customized_eps_guidance, 120), std=4)',
#  'winsorize(ts_backfill(max_ebit_guidance, 120), std=4)',
#  'winsorize(ts_backfill(max_ebitda_guidance, 120), std=4)',
#  'winsorize(ts_backfill(max_financing_cashflow_guidance, 120), std=4)',
#  'winsorize(ts_backfill(max_free_cash_flow_guidance, 120), std=4)',
#  'winsorize(ts_backfill(max_free_cashflow_guidance, 120), std=4)',
#  'winsorize(ts_backfill(max_free_cashflow_per_share_guidance, 120), std=4)',
#  'winsorize(ts_backfill(max_gross_income_guidance, 120), std=4)',
#  'winsorize(ts_backfill(max_gross_income_guidance_2, 120), std=4)',
#  'winsorize(ts_backfill(max_investing_cashflow_guidance, 120), std=4)',
#  'winsorize(ts_backfill(max_investing_cashflow_guidance_2, 120), std=4)',
#  'winsorize(ts_backfill(max_net_debt_guidance, 120), std=4)',
#  'winsorize(ts_backfill(max_net_income_guidance, 120), std=4)',
#  'winsorize(ts_backfill(max_net_profit_guidance, 120), std=4)',
#  'winsorize(ts_backfill(max_operating_cashflow_guidance, 120), std=4)',
#  'winsorize(ts_backfill(max_operating_cashflow_guidance_2, 120), std=4)',
#  'winsorize(ts_backfill(max_pretax_profit_guidance, 120), std=4)',
#  'winsorize(ts_backfill(max_reported_eps_guidance, 120), std=4)',
#  'winsorize(ts_backfill(max_reported_eps_guidance_2, 120), std=4)',
#  'winsorize(ts_backfill(max_reported_pretax_income_guidance, 120), std=4)',
#  'winsorize(ts_backfill(max_reported_pretax_income_guidance_2, 120), std=4)',
#  'winsorize(ts_backfill(max_research_development_expense_guidance, 120), std=4)',
#  'winsorize(ts_backfill(max_selling_general_admin_guidance, 120), std=4)',
#  'winsorize(ts_backfill(max_share_buyback_guidance, 120), std=4)',
#  'winsorize(ts_backfill(max_shareholders_equity_guidance, 120), std=4)',
#  'winsorize(ts_backfill(max_shares_outstanding_guidance, 120), std=4)',
#  'winsorize(ts_backfill(max_stock_option_expense_guidance, 120), std=4)',
#  'winsorize(ts_backfill(max_tangible_book_value_per_share_guidance, 120), std=4)',
#  'winsorize(ts_backfill(max_total_assets_guidance, 120), std=4)',
#  'winsorize(ts_backfill(max_total_assets_guidance_2, 120), std=4)',
#  'winsorize(ts_backfill(max_total_goodwill_guidance, 120), std=4)',
#  'winsorize(ts_backfill(max_total_goodwill_guidance_2, 120), std=4)',
#  'winsorize(ts_backfill(median_sales_estimate, 120), std=4)',
#  'winsorize(ts_backfill(min_adjusted_funds_from_operations_adj_guidance, 120), std=4)',
#  'winsorize(ts_backfill(min_adjusted_funds_from_operations_guidance, 120), std=4)',
#  'winsorize(ts_backfill(min_adjusted_funds_from_operations_guidance_2, 120), std=4)',
#  'winsorize(ts_backfill(min_adjusted_net_income_guidance, 120), std=4)',
#  'winsorize(ts_backfill(min_basic_shares_guidance, 120), std=4)',
#  'winsorize(ts_backfill(min_book_value_per_share_guidance, 120), std=4)',
#  'winsorize(ts_backfill(min_capex_guidance, 120), std=4)',
#  'winsorize(ts_backfill(min_capital_expenditure_guidance, 120), std=4)',
#  'winsorize(ts_backfill(min_custom_eps_guidance, 120), std=4)',
#  'winsorize(ts_backfill(min_customized_eps_guidance, 120), std=4)',
#  'winsorize(ts_backfill(min_ebit_guidance, 120), std=4)',
#  'winsorize(ts_backfill(min_ebit_guidance_2, 120), std=4)',
#  'winsorize(ts_backfill(min_ebitda_guidance, 120), std=4)',
#  'winsorize(ts_backfill(min_financing_cashflow_guidance, 120), std=4)',
#  'winsorize(ts_backfill(min_financing_cashflow_guidance_2, 120), std=4)',
#  'winsorize(ts_backfill(min_free_cash_flow_guidance, 120), std=4)',
#  'winsorize(ts_backfill(min_free_cash_flow_per_share_guidance, 120), std=4)',
#  'winsorize(ts_backfill(min_free_cashflow_guidance, 120), std=4)',
#  'winsorize(ts_backfill(min_free_cashflow_per_share_guidance, 120), std=4)',
#  'winsorize(ts_backfill(min_funds_from_operations_guidance, 120), std=4)',
#  'winsorize(ts_backfill(min_gross_income_guidance, 120), std=4)',
#  'winsorize(ts_backfill(min_gross_income_guidance_2, 120), std=4)',
#  'winsorize(ts_backfill(min_investing_cashflow_guidance, 120), std=4)',
#  'winsorize(ts_backfill(min_investing_cashflow_guidance_2, 120), std=4)',
#  'winsorize(ts_backfill(min_net_debt_guidance, 120), std=4)',
#  'winsorize(ts_backfill(min_net_income_guidance, 120), std=4)',
#  'winsorize(ts_backfill(min_net_profit_guidance, 120), std=4)',
#  'winsorize(ts_backfill(min_operating_cashflow_guidance, 120), std=4)',
#  'winsorize(ts_backfill(min_pretax_profit_guidance, 120), std=4)',
#  'winsorize(ts_backfill(min_pretax_profit_guidance_2, 120), std=4)',
#  'winsorize(ts_backfill(min_reported_eps_guidance, 120), std=4)',
#  'winsorize(ts_backfill(min_research_development_expense_guidance, 120), std=4)',
#  'winsorize(ts_backfill(min_research_development_expense_guidance_2, 120), std=4)',
#  'winsorize(ts_backfill(min_sg_and_a_expense_guidance, 120), std=4)',
#  'winsorize(ts_backfill(min_share_buyback_guidance, 120), std=4)',
#  'winsorize(ts_backfill(min_share_count_guidance, 120), std=4)',
#  'winsorize(ts_backfill(min_shareholders_equity_guidance, 120), std=4)',
#  'winsorize(ts_backfill(min_shares_outstanding_guidance, 120), std=4)',
#  'winsorize(ts_backfill(min_stock_option_expense_guidance, 120), std=4)',
#  'winsorize(ts_backfill(min_stock_option_expense_guidance_2, 120), std=4)',
#  'winsorize(ts_backfill(min_tangible_book_value_per_share_guidance, 120), std=4)',
#  'winsorize(ts_backfill(min_tangible_book_value_per_share_guidance_2, 120), std=4)',
#  'winsorize(ts_backfill(min_total_assets_guidance, 120), std=4)',
#  'winsorize(ts_backfill(min_total_assets_guidance_2, 120), std=4)',
#  'winsorize(ts_backfill(min_total_goodwill_guidance, 120), std=4)',
#  'winsorize(ts_backfill(net_debt_actual_value, 120), std=4)',
#  'winsorize(ts_backfill(net_debt_amount, 120), std=4)',
#  'winsorize(ts_backfill(net_debt_max_guidance_qtr, 120), std=4)',
#  'winsorize(ts_backfill(net_debt_min_guidance_qtr, 120), std=4)',
#  'winsorize(ts_backfill(net_debt_reported_value, 120), std=4)',
#  'winsorize(ts_backfill(net_income_adjusted, 120), std=4)',
#  'winsorize(ts_backfill(net_income_total_2, 120), std=4)',
#  'winsorize(ts_backfill(net_profit_adjusted_min_guidance, 120), std=4)',
#  'winsorize(ts_backfill(net_profit_adjusted_value, 120), std=4)',
#  'winsorize(ts_backfill(net_profit_reported_value, 120), std=4)',
#  'winsorize(ts_backfill(operating_cashflow_reported_value, 120), std=4)',
#  'winsorize(ts_backfill(operating_profit_before_depr_amort, 120), std=4)',
#  'winsorize(ts_backfill(operating_profit_before_depr_amort_max_guidance_qtr, 120), std=4)',
#  'winsorize(ts_backfill(operating_profit_before_depr_amort_min_guidance_qtr, 120), std=4)',
#  'winsorize(ts_backfill(operating_profit_before_interest_tax, 120), std=4)',
#  'winsorize(ts_backfill(operating_profit_max_guidance_qtr, 120), std=4)',
#  'winsorize(ts_backfill(pretax_income_actual_reported_value, 120), std=4)',
#  'winsorize(ts_backfill(pretax_income_max_guidance_qtr, 120), std=4)',
#  'winsorize(ts_backfill(pretax_income_reported, 120), std=4)',
#  'winsorize(ts_backfill(pretax_income_reported_min_guidance, 120), std=4)',
#  'winsorize(ts_backfill(pretax_income_reported_min_guidance_qtr, 120), std=4)',
#  'winsorize(ts_backfill(pretax_income_reported_value, 120), std=4)',
#  'winsorize(ts_backfill(pretax_income_standalone_value, 120), std=4)',
#  'winsorize(ts_backfill(pretax_income_total, 120), std=4)',
#  'winsorize(ts_backfill(reporting_currency_code_9, 120), std=4)',
#  'winsorize(ts_backfill(research_development_expense, 120), std=4)',
#  'winsorize(ts_backfill(research_development_expense_actual_value, 120), std=4)',
#  'winsorize(ts_backfill(research_development_expense_reported_value, 120), std=4)',
#  'winsorize(ts_backfill(research_development_max_guidance, 120), std=4)',
#  'winsorize(ts_backfill(sales_estimate_average, 120), std=4)',
#  'winsorize(ts_backfill(sales_estimate_average_annual, 120), std=4)',
#  'winsorize(ts_backfill(sales_estimate_average_quarterly, 120), std=4)',
#  'winsorize(ts_backfill(sales_estimate_count, 120), std=4)',
#  'winsorize(ts_backfill(sales_estimate_count_2, 120), std=4)',
#  'winsorize(ts_backfill(sales_estimate_count_quarterly, 120), std=4)',
#  'winsorize(ts_backfill(sales_estimate_dispersion, 120), std=4)',
#  'winsorize(ts_backfill(sales_estimate_maximum, 120), std=4)',
#  'winsorize(ts_backfill(sales_estimate_maximum_quarterly, 120), std=4)',
#  'winsorize(ts_backfill(sales_estimate_median_quarterly, 120), std=4)',
#  'winsorize(ts_backfill(sales_estimate_median_value, 120), std=4)',
#  'winsorize(ts_backfill(sales_estimate_minimum, 120), std=4)',
#  'winsorize(ts_backfill(sales_estimate_minimum_quarterly, 120), std=4)',
#  'winsorize(ts_backfill(sales_estimate_standard_deviation, 120), std=4)',
#  'winsorize(ts_backfill(sales_estimate_stddev_quarterly, 120), std=4)',
#  'winsorize(ts_backfill(sales_guidance_value, 120), std=4)',
#  'winsorize(ts_backfill(sales_guidance_value_quarterly, 120), std=4)',
#  'winsorize(ts_backfill(sales_max_guidance_quarterly, 120), std=4)',
#  'winsorize(ts_backfill(sales_max_guidance_value, 120), std=4)',
#  'winsorize(ts_backfill(sales_min_guidance_quarterly, 120), std=4)',
#  'winsorize(ts_backfill(sales_min_guidance_value, 120), std=4)',
#  'winsorize(ts_backfill(selling_general_admin_expense, 120), std=4)',
#  'winsorize(ts_backfill(selling_general_admin_expense_actual_value, 120), std=4)',
#  'winsorize(ts_backfill(selling_general_admin_expense_max_guidance_qtr, 120), std=4)',
#  'winsorize(ts_backfill(selling_general_admin_expense_reported_value, 120), std=4)',
#  'winsorize(ts_backfill(sg_and_admin_min_guidance_value, 120), std=4)',
#  'winsorize(ts_backfill(shareholders_equity_actual_value, 120), std=4)',
#  'winsorize(ts_backfill(shareholders_equity_max_guidance, 120), std=4)',
#  'winsorize(ts_backfill(shareholders_equity_min_guidance, 120), std=4)',
#  'winsorize(ts_backfill(shareholders_equity_reported_value, 120), std=4)',
#  'winsorize(ts_backfill(shareholders_equity_total_2, 120), std=4)',
#  'winsorize(ts_backfill(shares_outstanding_max_guidance, 120), std=4)',
#  'winsorize(ts_backfill(stock_option_expense_max_guidance_qtr, 120), std=4)',
#  'winsorize(ts_backfill(tangible_book_value_per_share_max_guidance, 120), std=4)',
#  'winsorize(ts_backfill(total_assets_amount, 120), std=4)',
#  'winsorize(ts_backfill(total_assets_reported_value, 120), std=4)',
#  'winsorize(ts_backfill(total_goodwill_actual_value, 120), std=4)',
#  'winsorize(ts_backfill(total_goodwill_amount, 120), std=4)',
#  'winsorize(ts_backfill(total_goodwill_reported_value, 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(actuals_reporting_currency), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(actuals_reporting_currency), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_ads1detailafv110_bk), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_ads1detailafv110_bk), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_ads1detailafv110_estvalue), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_ads1detailafv110_estvalue), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_ads1detailafv110_person), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_ads1detailafv110_person), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_ads1detailafv110_prevval), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_ads1detailafv110_prevval), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_ads1detailqfv110_bk), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_ads1detailqfv110_bk), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_ads1detailqfv110_estvalue), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_ads1detailqfv110_estvalue), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_ads1detailqfv110_person), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_ads1detailqfv110_person), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_ads1detailqfv110_prevval), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_ads1detailqfv110_prevval), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_adxqfv110_down), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_adxqfv110_down), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_adxqfv110_high), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_adxqfv110_high), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_adxqfv110_low), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_adxqfv110_low), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_adxqfv110_mean), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_adxqfv110_mean), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_adxqfv110_median), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_adxqfv110_median), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_adxqfv110_numest), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_adxqfv110_numest), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_adxqfv110_pu), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_adxqfv110_pu), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_ady_down), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_ady_down), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_ady_high), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_ady_high), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_ady_low), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_ady_low), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_ady_mean), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_ady_mean), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_ady_median), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_ady_median), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_ady_numest), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_ady_numest), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_ady_pu), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_ady_pu), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_afv4_actual), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_afv4_actual), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_afv4_maxguidance), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_afv4_maxguidance), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_afv4_minguidance), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_afv4_minguidance), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_bac1actualqfv110_actual), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_bac1actualqfv110_actual), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_bac1actualqfv110_item), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_bac1actualqfv110_item), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_bac1conafv110_item), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_bac1conafv110_item), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_bac1conltv110_item), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_bac1conltv110_item), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_bac1conqfv110_item), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_bac1conqfv110_item), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_bac1conrecv110_item), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_bac1conrecv110_item), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_bac1detailafv110_item), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_bac1detailafv110_item), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_bac1detaillt_item), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_bac1detaillt_item), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_bac1detailqfv110_item), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_bac1detailqfv110_item), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_bac1detailrec_item), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_bac1detailrec_item), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_basicafv4_actual), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_basicafv4_actual), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_basicconafv110_down), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_basicconafv110_down), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_basicconafv110_high), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_basicconafv110_high), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_basicconafv110_low), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_basicconafv110_low), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_basicconafv110_mean), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_basicconafv110_mean), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_basicconafv110_median), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_basicconafv110_median), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_basicconafv110_numest), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_basicconafv110_numest), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_basicconafv110_pu), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_basicconafv110_pu), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_basicconltv110_down), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_basicconltv110_down), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_basicconltv110_high), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_basicconltv110_high), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_basicconltv110_low), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_basicconltv110_low), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_basicconltv110_mean), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_basicconltv110_mean), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_basicconltv110_median), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_basicconltv110_median), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_basicconltv110_numest), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_basicconltv110_numest), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_basicconltv110_pu), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_basicconltv110_pu), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_basicconqfv110_down), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_basicconqfv110_down), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_basicconqfv110_high), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_basicconqfv110_high), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_basicconqfv110_low), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_basicconqfv110_low), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_basicconqfv110_mean), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_basicconqfv110_mean), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_basicconqfv110_median), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_basicconqfv110_median), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_basicconqfv110_numest), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_basicconqfv110_numest), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_basicconqfv110_pu), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_basicconqfv110_pu), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_basicdetaillt_bk), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_basicdetaillt_bk), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_basicdetaillt_estvalue), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_basicdetaillt_estvalue), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_basicdetaillt_person), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_basicdetaillt_person), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_basicdetaillt_prevval), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_basicdetaillt_prevval), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_basicdetailqfv110_bk), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_basicdetailqfv110_bk), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_basicdetailqfv110_estvalue), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_basicdetailqfv110_estvalue), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_basicdetailqfv110_person), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_basicdetailqfv110_person), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_basicdetailqfv110_prevval), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_basicdetailqfv110_prevval), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_basicdetailrec_bk), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_basicdetailrec_bk), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_basicdetailrec_person), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_basicdetailrec_person), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_basicdetailrec_ratingvalue), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_basicdetailrec_ratingvalue), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_basicqfv4_actual), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_basicqfv4_actual), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_basicqfv4_maxguidance), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_basicqfv4_maxguidance), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_basicqfv4_minguidance), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_basicqfv4_minguidance), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_baz1v110_bk), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_baz1v110_bk), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_baz1v110_estvalue), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_baz1v110_estvalue), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_baz1v110_person), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_baz1v110_person), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_baz1v110_prevval), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_baz1v110_prevval), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_buy), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_buy), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_cuo1actualqfv110_actual), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_cuo1actualqfv110_actual), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_cuo1actualqfv110_item), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_cuo1actualqfv110_item), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_cuo1conafv110_item), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_cuo1conafv110_item), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_cuo1conqfv110_item), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_cuo1conqfv110_item), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_cuo1detailafv110_item), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_cuo1detailafv110_item), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_cuo1detailqfv110_item), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_cuo1detailqfv110_item), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_cuo1guidaf_item), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_cuo1guidaf_item), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_cuo1guidaf_maxguidance), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_cuo1guidaf_maxguidance), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_cuo1guidaf_minguidance), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_cuo1guidaf_minguidance), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_dei2laf_item), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_dei2laf_item), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_dei2lqfv110_item), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_dei2lqfv110_item), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_dei3lafv110_item), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_dei3lafv110_item), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_dei3lltv110_item), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_dei3lltv110_item), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_dei3lqfv110_item), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_dei3lqfv110_item), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_dei3lrec_item), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_dei3lrec_item), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_detailltv4_est), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_detailltv4_est), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_detailltv4_preest), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_detailltv4_preest), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_detailltv4v104_est), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_detailltv4v104_est), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_detailltv4v104_preest), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_detailltv4v104_preest), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_detailrecv4_est), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_detailrecv4_est), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_detailrecv4v104_est), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_detailrecv4v104_est), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_dez1afv4_est), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_dez1afv4_est), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_dez1afv4_preest), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_dez1afv4_preest), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_dez1basicafv4_est), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_dez1basicafv4_est), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_dez1basicafv4_preest), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_dez1basicafv4_preest), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_dez1basicafv4v104_est), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_dez1basicafv4v104_est), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_dez1basicafv4v104_preest), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_dez1basicafv4v104_preest), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_dez1basicqfv4_est), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_dez1basicqfv4_est), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_dez1basicqfv4_preest), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_dez1basicqfv4_preest), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_dez1basicqfv4v104_est), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_dez1basicqfv4v104_est), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_dez1basicqfv4v104_preest), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_dez1basicqfv4v104_preest), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_dez1qfv4_est), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_dez1qfv4_est), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_dez1qfv4_preest), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_dez1qfv4_preest), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_dez1safv4_est), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_dez1safv4_est), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_dez1safv4_preest), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_dez1safv4_preest), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_eaz1laf_bk), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_eaz1laf_bk), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_eaz1laf_estvalue), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_eaz1laf_estvalue), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_eaz1laf_person), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_eaz1laf_person), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_eaz1laf_prevval), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_eaz1laf_prevval), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_eaz1lqfv110_bk), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_eaz1lqfv110_bk), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_eaz1lqfv110_estvalue), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_eaz1lqfv110_estvalue), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_eaz1lqfv110_person), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_eaz1lqfv110_person), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_eaz1lqfv110_prevval), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_eaz1lqfv110_prevval), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_eaz2lafv110_bk), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_eaz2lafv110_bk), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_eaz2lafv110_estvalue), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_eaz2lafv110_estvalue), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_eaz2lafv110_person), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_eaz2lafv110_person), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_eaz2lafv110_prevval), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_eaz2lafv110_prevval), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_eaz2lltv110_bk), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_eaz2lltv110_bk), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_eaz2lltv110_estvalue), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_eaz2lltv110_estvalue), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_eaz2lltv110_person), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_eaz2lltv110_person), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_eaz2lltv110_prevval), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_eaz2lltv110_prevval), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_eaz2lqfv110_bk), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_eaz2lqfv110_bk), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_eaz2lqfv110_estvalue), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_eaz2lqfv110_estvalue), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_eaz2lqfv110_person), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_eaz2lqfv110_person), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_eaz2lqfv110_prevval), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_eaz2lqfv110_prevval), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_eaz2lrec_bk), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_eaz2lrec_bk), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_eaz2lrec_person), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_eaz2lrec_person), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_eaz2lrec_ratingvalue), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_eaz2lrec_ratingvalue), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_fsactualafv4_actual), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_fsactualafv4_actual), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_fsactualafv4_item), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_fsactualafv4_item), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_fsactualqfv4_actual), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_fsactualqfv4_actual), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_fsactualqfv4_item), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_fsactualqfv4_item), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_fsdetailltv4v104_item), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_fsdetailltv4v104_item), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_fsdetailrecv4v104_item), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_fsdetailrecv4v104_item), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_fsdtlestmtafv4_item), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_fsdtlestmtafv4_item), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_fsdtlestmtbscqv104_item), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_fsdtlestmtbscqv104_item), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_fsdtlestmtbscv104_item), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_fsdtlestmtbscv104_item), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_fsdtlestmtqfv4_item), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_fsdtlestmtqfv4_item), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_fsdtlestmtsafv4_item), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_fsdtlestmtsafv4_item), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_fsgdncbscv4_maxguidance), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_fsgdncbscv4_maxguidance), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_fsgdncbscv4_minguidance), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_fsgdncbscv4_minguidance), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_fsguidanceafv4_item), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_fsguidanceafv4_item), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_fsguidanceafv4_maxguidance), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_fsguidanceafv4_maxguidance), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_fsguidanceafv4_minguidance), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_fsguidanceafv4_minguidance), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_fsguidancebasicqfv4_item), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_fsguidancebasicqfv4_item), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_fsguidanceqfv4_item), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_fsguidanceqfv4_item), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_fsguidanceqfv4_maxguidance), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_fsguidanceqfv4_maxguidance), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_fsguidanceqfv4_minguidance), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_fsguidanceqfv4_minguidance), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_guiafv4_est), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_guiafv4_est), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_guibasicqfv4_est), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_guibasicqfv4_est), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_guiqfv4_est), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_guiqfv4_est), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_hold), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_hold), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_mark), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_norec), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_norec), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_qfv4_actual), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_qfv4_actual), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_qfv4_maxguidance), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_qfv4_maxguidance), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_qfv4_minguidance), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_qfv4_minguidance), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_total_rec), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_total_rec), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(anl4_under), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(anl4_under), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(dividend_estimate_value), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(dividend_estimate_value), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(dividend_previous_estimate_value), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(dividend_previous_estimate_value), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(eps_estimate_value), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(eps_estimate_value), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(eps_previous_estimate_value), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(eps_previous_estimate_value), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(estimate_value_currency_code), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(estimate_value_currency_code), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(estimate_value_currency_code_detail_qtr), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(estimate_value_currency_code_detail_qtr), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(estimate_value_currency_code_qtr), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(estimate_value_currency_code_qtr), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(guidance_estimate_value), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(guidance_estimate_value), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(guidance_previous_estimate_value_qtr), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(guidance_previous_estimate_value_qtr), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(guidance_value_currency_code_qtr), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(guidance_value_currency_code_qtr), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(maximum_guidance_value), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(maximum_guidance_value), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(minimum_guidance_value), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(minimum_guidance_value), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(previous_guidance_estimate), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(previous_guidance_estimate), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(previous_guidance_value_annual), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(previous_guidance_value_annual), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(previous_quarterly_guidance_estimate), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(previous_quarterly_guidance_estimate), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(previous_recommendation_value), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(previous_recommendation_value), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(sales_estimate_value), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(sales_estimate_value), 120), std=4)',
#  'winsorize(ts_backfill(vec_avg(sales_previous_estimate_value), 120), std=4)',
#  'winsorize(ts_backfill(vec_sum(sales_previous_estimate_value), 120), std=4)']

# %% [markdown]
# ## 5, Alpha factory
# <div style="margin-left: 20px;">
# 在factory方法中将数据字段与操作符组装成alpha表达式
# </div>

# %%
first_order = first_order_factory(pc_fields, ts_ops)
print(first_order[:10])
print(len(first_order))
# Out:
# ['winsorize(ts_backfill(actual_cashflow_per_share_value_quarterly, 120), std=4)', 'ts_rank(winsorize(ts_backfill(actual_cashflow_per_share_value_quarterly, 120), std=4), 5)', 'ts_rank(winsorize(ts_backfill(actual_cashflow_per_share_value_quarterly, 120), std=4), 22)', 'ts_rank(winsorize(ts_backfill(actual_cashflow_per_share_value_quarterly, 120), std=4), 66)', 'ts_rank(winsorize(ts_backfill(actual_cashflow_per_share_value_quarterly, 120), std=4), 120)', 'ts_rank(winsorize(ts_backfill(actual_cashflow_per_share_value_quarterly, 120), std=4), 240)', 'ts_zscore(winsorize(ts_backfill(actual_cashflow_per_share_value_quarterly, 120), std=4), 5)', 'ts_zscore(winsorize(ts_backfill(actual_cashflow_per_share_value_quarterly, 120), std=4), 22)', 'ts_zscore(winsorize(ts_backfill(actual_cashflow_per_share_value_quarterly, 120), std=4), 66)', 'ts_zscore(winsorize(ts_backfill(actual_cashflow_per_share_value_quarterly, 120), std=4), 120)']
# 46872

# %% [markdown]
# ## 6, 回测前载入
#
# <div style="margin-left: 20px;">
# 1, alpha表达式与初始decay配对
# </div>
#
# <div style="margin-left: 20px;">
# 2, random shuffle
# </div>
#
# <div style="margin-left: 20px;">
# 2, Load task pool数据结构
# </div>

# %%
# 赋予alpha表达式一个初始decay
init_decay = 6
fo_alpha_list = []

for alpha in first_order:
    fo_alpha_list.append((alpha, init_decay))

# 随机采样快速评估一个数据集的潜力
random.shuffle(fo_alpha_list)

print("数量: %s"%len(fo_alpha_list))
print(fo_alpha_list[:5])
# Out:
# 数量: 46872
# [('ts_quantile(winsorize(ts_backfill(vec_sum(anl4_dez1basicqfv4v104_preest), 120), std=4), 22)', 6), ('ts_zscore(winsorize(ts_backfill(min_capital_expenditure_guidance, 120), std=4), 22)', 6), ('ts_delay(winsorize(ts_backfill(est_tot_goodwill, 120), std=4), 240)', 6), ('ts_std_dev(winsorize(ts_backfill(vec_sum(anl4_detailltv4_preest), 120), std=4), 240)', 6), ('ts_delta(winsorize(ts_backfill(anl4_totassets_std, 120), std=4), 22)', 6)]

# %%
# Load alphas to task pools
fo_pools = load_task_pool(fo_alpha_list, 5, 5)
print(fo_pools[0])
# Out:
# [[('ts_quantile(winsorize(ts_backfill(vec_sum(anl4_dez1basicqfv4v104_preest), 120), std=4), 22)', 6), ('ts_zscore(winsorize(ts_backfill(min_capital_expenditure_guidance, 120), std=4), 22)', 6), ('ts_delay(winsorize(ts_backfill(est_tot_goodwill, 120), std=4), 240)', 6), ('ts_std_dev(winsorize(ts_backfill(vec_sum(anl4_detailltv4_preest), 120), std=4), 240)', 6), ('ts_delta(winsorize(ts_backfill(anl4_totassets_std, 120), std=4), 22)', 6)], [('ts_delay(winsorize(ts_backfill(anl4_afv4_div_high, 120), std=4), 22)', 6), ('ts_zscore(winsorize(ts_backfill(net_debt_reported_value, 120), std=4), 240)', 6), ('ts_arg_max(winsorize(ts_backfill(vec_sum(anl4_dez1safv4_est), 120), std=4), 5)', 6), ('ts_zscore(winsorize(ts_backfill(anl4_totgw_mean, 120), std=4), 240)', 6), ('ts_scale(winsorize(ts_backfill(total_assets_reported_value, 120), std=4), 120)', 6)], [('ts_std_dev(winsorize(ts_backfill(vec_sum(anl4_ads1detailafv110_prevval), 120), std=4), 66)', 6), ('ts_mean(winsorize(ts_backfill(free_cash_flow_per_share_actual_value, 120), std=4), 66)', 6), ('ts_delay(winsorize(ts_backfill(vec_sum(anl4_dez1basicqfv4_est), 120), std=4), 22)', 6), ('ts_std_dev(winsorize(ts_backfill(anl4_ptpr_mean, 120), std=4), 5)', 6), ('ts_delay(winsorize(ts_backfill(vec_avg(anl4_cuo1guidaf_item), 120), std=4), 66)', 6)], [('ts_quantile(winsorize(ts_backfill(vec_avg(anl4_fsguidanceafv4_minguidance), 120), std=4), 22)', 6), ('ts_quantile(winsorize(ts_backfill(anl4_tbvps_high, 120), std=4), 120)', 6), ('ts_delay(winsorize(ts_backfill(vec_sum(anl4_eaz2lqfv110_bk), 120), std=4), 120)', 6), ('winsorize(ts_backfill(vec_avg(anl4_basicdetaillt_person), 120), std=4)', 6), ('ts_arg_max(winsorize(ts_backfill(vec_sum(anl4_basicdetailrec_bk), 120), std=4), 120)', 6)], [('ts_delay(winsorize(ts_backfill(anl4_rd_exp_median, 120), std=4), 22)', 6), ('ts_arg_max(winsorize(ts_backfill(anl4_qf_az_hgih_vid, 120), std=4), 240)', 6), ('ts_delay(winsorize(ts_backfill(cashflow_per_share_min_guidance_quarterly, 120), std=4), 66)', 6), ('ts_delta(winsorize(ts_backfill(sales_estimate_median_value, 120), std=4), 120)', 6), ('ts_mean(winsorize(ts_backfill(cash_flow_financing_max_guidance, 120), std=4), 120)', 6)]]

# %% [markdown]
# ## 7, 回测

# %%
# Simulate First Order
multi_simulate(fo_pools, "SUBINDUSTRY", "USA", "TOP3000", 0)
# Out:
# b'{"user":{"id":"HS29282"},"token":{"expiry":14400.0},"permissions":["BEFORE_AND_AFTER_PERFORMANCE_V2","BRAIN_LABS","BRAIN_LABS_JUPYTER_LAB","CONSULTANT","MULTI_SIMULATION","PROD_ALPHAS","REFERRAL","SUPER_ALPHA","VISUALIZATION","WORKDAY"]}'
# pool 0 task 4 post done
# pool 0 task 4 simulate done
# pool 1 task 4 post done
# pool 1 task 4 simulate done
# pool 2 task 4 post done
# pool 2 task 4 simulate done
# pool 3 task 4 post done
# pool 3 task 4 simulate done
# pool 4 task 4 post done
# pool 4 task 4 simulate done
# pool 5 task 4 post done
# pool 5 task 4 simulate done
# pool 6 task 4 post done
# pool 6 task 4 simulate done
# pool 7 task 4 post done
# pool 7 task 4 simulate done
# pool 8 task 4 post done
# pool 8 task 4 simulate done
# pool 9 task 4 post done
# pool 9 task 4 simulate done
# pool 10 task 4 post done
# pool 10 task 4 simulate done
# pool 11 task 4 post done
# pool 11 task 4 simulate done
# pool 12 task 4 post done
# pool 12 task 4 simulate done
# pool 13 task 4 post done
# pool 13 task 4 simulate done
# pool 14 task 4 post done
# pool 14 task 4 simulate done
# pool 15 task 4 post done
# pool 15 task 4 simulate done
# pool 16 task 4 post done
# Not complete : https://api.worldquantbrain.com/simulations/1E6JRH1b44kcaTQxGbQiDZn
# pool 16 task 4 simulate done
# pool 17 task 4 post done
# pool 17 task 4 simulate done
# pool 18 task 4 post done
# pool 18 task 4 simulate done
# pool 19 task 4 post done
# pool 19 task 4 simulate done
# pool 20 task 4 post done
# pool 20 task 4 simulate done
# pool 21 task 4 post done
# pool 21 task 4 simulate done
# pool 22 task 4 post done
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 2
#       1 # Simulate First Order
# ----> 2 multi_simulate(fo_pools, "SUBINDUSTRY", "USA", "TOP3000", 0)
#
# File D:\ProgramFile2_OR\pythonProgramUpStage\wqb\wqb\machine_lib.py:216, in multi_simulate(alpha_pools, neut, region, universe, start)
#     214         break
#     215     #print("Sleeping for " + simulation_progress.headers["Retry-After"] + " seconds")
# --> 216     sleep(float(simulation_progress.headers["Retry-After"]))
#     218 status = simulation_progress.json().get("status", 0)
#     219 if status != "COMPLETE":
#
# KeyboardInterrupt:

# %% [markdown]
# ## 8, 筛选Alpha
#
#
# <div style="margin-left: 20px;">
# 1, get_alpha：截取有潜力提升表现至可以提交的alpha进入下一阶
# </div>
#
# <div style="margin-left: 20px;">
# 2, 剪枝Prune：精减相似alpha，提高回测资源利用率
# </div>

# %%
## get promising alphas to improve in the next order
fo_tracker = get_alphas("11-12", "11-16", 1.2, 0.7, "USA", 100, "track")
print(len(fo_tracker))
# Out:
# b'{"user":{"id":"HS29282"},"token":{"expiry":14400.0},"permissions":["BEFORE_AND_AFTER_PERFORMANCE_V2","BRAIN_LABS","BRAIN_LABS_JUPYTER_LAB","CONSULTANT","MULTI_SIMULATION","PROD_ALPHAS","REFERRAL","SUPER_ALPHA","VISUALIZATION","WORKDAY"]}'
# 0
# ['om5OM7OJ', "group_zscore(-inverse(winsorize(ts_backfill(fnd6_newqv1300_stkcoq, 120), std=4)),densify(bucket(group_rank(cap,sector),range='0,1,0.1')))", 1.22, 0.0735, 0.9, 0.001856, '2025-11-15T00:26:00-05:00', 6]
# ['O0Yjj6KY', '-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 5)', -2.72, 0.802, -1.23, -0.00041, '2025-11-12T06:48:49-05:00', 6]
# ['6X8QNgVY', '-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 120)', -1.73, 0.0902, -1.09, -0.001109, '2025-11-12T06:33:34-05:00', 6]
# count: 4
# 3

# %% [markdown]
# #### Prune 剪枝

# %%
fo_layer = prune(fo_tracker, 'anl4', 5)

# 剪枝后数量
print(len(fo_layer))
# Out:
# 3

# %% [markdown]
# ## 9, 二阶提升
# ### ts_ops(field, days) -> group_ops(ts_ops(field, days), group)

# %%
so_alpha_list = []
group_ops = ["group_neutralize", "group_rank", "group_zscore"]

for expr, decay in fo_layer:
    for alpha in get_group_second_order_factory([expr], group_ops, "USA"):
        so_alpha_list.append((alpha,decay))

random.shuffle(so_alpha_list)
print(len(so_alpha_list))
print(so_alpha_list[:3])
# Out:
# 207
# [("group_neutralize(group_zscore(-inverse(winsorize(ts_backfill(fnd6_newqv1300_stkcoq, 120), std=4)),densify(bucket(group_rank(cap,sector),range='0,1,0.1'))),densify(bucket(group_rank(assets, sector),range='0.1, 1, 0.1')))", 6), ('group_neutralize(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 5),densify(sta1_allc10))', 24), ("group_zscore(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 5),densify(bucket(rank(assets),range='0.1, 1, 0.1')))", 24)]

# %% [markdown]
# ### Simulate second order

# %%
so_pools = load_task_pool(so_alpha_list, 6, 6)
multi_simulate(so_pools, 'SUBINDUSTRY', 'USA', 'TOP3000', 0)
# Out:
# b'{"user":{"id":"HS29282"},"token":{"expiry":14400.0},"permissions":["BEFORE_AND_AFTER_PERFORMANCE_V2","BRAIN_LABS","BRAIN_LABS_JUPYTER_LAB","CONSULTANT","MULTI_SIMULATION","PROD_ALPHAS","REFERRAL","SUPER_ALPHA","VISUALIZATION","WORKDAY"]}'
# pool 0 task 5 post done
# pool 0 task 5 simulate done
# pool 1 task 5 post done
# pool 1 task 5 simulate done
# pool 2 task 5 post done
# pool 2 task 5 simulate done
# pool 3 task 5 post done
# pool 3 task 5 simulate done
# pool 4 task 5 post done
# pool 4 task 5 simulate done
# pool 5 task 4 post done
# pool 5 task 4 simulate done
# Simulate done

# %% [markdown]
# ## 10，三阶提升
# group_ops(ts_ops(field, days), group) -> trade_when(entre_event, group_ops(ts_ops(field, days), group), exit_event)

# %%
## get promising alphas from second order to improve in the third order
so_tracker = get_alphas("11-14", "11-16", 1.3, 0.8, "USA", 200, "track")

so_layer = prune(so_tracker, 'anl4', 5)
th_alpha_list = []

for expr, decay in so_layer:
    for alpha in trade_when_factory("trade_when",expr,"USA"):
        th_alpha_list.append((alpha,decay))

random.shuffle(th_alpha_list)        
print("三阶表达式数量:%s"%len(th_alpha_list))
# Out:
# b'{"user":{"id":"HS29282"},"token":{"expiry":14400.0},"permissions":["BEFORE_AND_AFTER_PERFORMANCE_V2","BRAIN_LABS","BRAIN_LABS_JUPYTER_LAB","CONSULTANT","MULTI_SIMULATION","PROD_ALPHAS","REFERRAL","SUPER_ALPHA","VISUALIZATION","WORKDAY"]}'
# 0
# ['qMrZelVP', "group_neutralize(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 5),densify(bucket(rank(ts_std_dev(returns,20)),range = '0.1, 1, 0.1')))", 2.69, 0.7832, 1.21, 0.000407, '2025-11-15T05:44:03-05:00', 24]
# ['E5WAAkOP', "group_neutralize(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 5),densify(bucket(group_rank(cap, sector),range='0.1, 1, 0.1')))", 2.69, 0.7821, 1.21, 0.000405, '2025-11-15T05:31:13-05:00', 24]
# ['rKgmvRkj', "group_neutralize(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 5),densify(bucket(group_rank(cap, sector),range='0.1, 1, 0.1')))", 2.69, 0.7821, 1.21, 0.000405, '2025-11-15T05:19:52-05:00', 24]
# ['889qkoOm', "group_neutralize(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 5),densify(bucket(rank(cap), range='0.1, 1, 0.1')))", 2.68, 0.7822, 1.21, 0.000406, '2025-11-15T05:47:50-05:00', 24]
# ['wpxVXaGY', "group_zscore(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 5),densify(bucket(rank(cap), range='0.1, 1, 0.1')))", 2.68, 0.7789, 1.21, 0.000406, '2025-11-15T05:44:22-05:00', 24]
# ['Vkjoq97J', "group_zscore(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 5),densify(bucket(group_rank(cap, sector),range='0.1, 1, 0.1')))", 2.67, 0.7794, 1.2, 0.000404, '2025-11-15T05:54:05-05:00', 24]
# ['qMrZkbrE', "group_neutralize(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 5),densify(bucket(group_rank(assets, sector),range='0.1, 1, 0.1')))", 2.67, 0.7823, 1.2, 0.000403, '2025-11-15T05:48:32-05:00', 24]
# ['kqr5RVgz', 'group_zscore(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 5),densify(market))', 2.67, 0.7789, 1.21, 0.000411, '2025-11-15T05:38:32-05:00', 24]
# ['6XVb3OwJ', "group_zscore(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 5),densify(bucket(group_rank(assets, sector),range='0.1, 1, 0.1')))", 2.66, 0.7796, 1.19, 0.000401, '2025-11-15T05:54:30-05:00', 24]
# ['d5VwAo6j', "group_zscore(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 5),densify(bucket(rank(ts_std_dev(returns,20)),range = '0.1, 1, 0.1')))", 2.66, 0.7802, 1.2, 0.000406, '2025-11-15T05:20:52-05:00', 24]
# ['JjELYwvE', 'group_neutralize(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 5),densify(market))', 2.65, 0.7799, 1.2, 0.000408, '2025-11-15T05:54:05-05:00', 24]
# ['xA8aMq7p', 'group_neutralize(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 5),densify(pv13_r2_min20_3000_sector))', 2.65, 0.772, 1.21, 0.000417, '2025-11-15T05:35:24-05:00', 24]
# ['LLaxAr3L', 'group_neutralize(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 5),densify(pv13_r2_min20_3000_sector))', 2.65, 0.772, 1.21, 0.000417, '2025-11-15T05:20:52-05:00', 24]
# ['RRQLqWp0', 'group_neutralize(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 5),densify(sta1_top3000c50))', 2.62, 0.7885, 1.13, 0.000372, '2025-11-15T05:54:30-05:00', 24]
# ['E5WAY7eP', 'group_neutralize(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 5),densify(industry))', 2.62, 0.7655, 1.19, 0.000414, '2025-11-15T05:54:05-05:00', 24]
# ['om5ewp9n', 'group_neutralize(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 5),densify(sta1_top3000c20))', 2.62, 0.7853, 1.15, 0.000387, '2025-11-15T05:47:50-05:00', 24]
# ['QPkdeAOg', 'group_neutralize(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 5),densify(sector))', 2.62, 0.7771, 1.18, 0.000405, '2025-11-15T05:40:18-05:00', 24]
# ['2rzkEEQ5', 'group_zscore(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 5),densify(sta2_top3000_fact4_c10))', 2.62, 0.785, 1.15, 0.000385, '2025-11-15T05:36:10-05:00', 24]
# ['QPkdLK8w', "group_neutralize(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 5),densify(bucket(rank(close*volume),range = '0.1, 1, 0.1')))", 2.62, 0.7841, 1.17, 0.0004, '2025-11-15T05:19:41-05:00', 24]
# ['d5VwA1rg', 'group_zscore(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 5),densify(sta2_top3000_fact4_c10))', 2.62, 0.785, 1.15, 0.000385, '2025-11-15T05:19:41-05:00', 24]
# ['A1ZdKdPR', 'group_zscore(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 5),densify(sector))', 2.6, 0.7735, 1.17, 0.000404, '2025-11-15T05:23:22-05:00', 24]
# ['kqr5RM8z', 'group_zscore(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 5),densify(industry))', 2.58, 0.7605, 1.16, 0.000405, '2025-11-15T05:40:18-05:00', 24]
# ['WjQmkPeo', "group_zscore(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 5),densify(bucket(rank(close*volume),range = '0.1, 1, 0.1')))", 2.58, 0.7814, 1.15, 0.000394, '2025-11-15T05:38:32-05:00', 24]
# ['gJOz7Mq0', 'group_neutralize(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 5),densify(sta1_allc20))', 2.57, 0.7851, 1.13, 0.000385, '2025-11-15T05:43:58-05:00', 24]
# ['O0PvEJgq', 'group_neutralize(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 5),densify(sta1_allc10))', 2.57, 0.7843, 1.13, 0.000386, '2025-11-15T05:19:49-05:00', 24]
# ['vRMV31xr', 'group_neutralize(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 5),densify(sta2_top3000_fact4_c10))', 2.56, 0.7852, 1.11, 0.000376, '2025-11-15T05:19:53-05:00', 24]
# ['xA8a01oN', "group_neutralize(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 5),densify(bucket(rank(assets),range='0.1, 1, 0.1')))", 2.56, 0.7878, 1.14, 0.000396, '2025-11-15T05:19:49-05:00', 24]
# ['WjQm6LJP', "group_zscore(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 5),densify(bucket(rank(assets),range='0.1, 1, 0.1')))", 2.56, 0.7844, 1.14, 0.000394, '2025-11-15T05:19:49-05:00', 24]
# ['mLRkebKW', 'group_zscore(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 5),densify(sta1_top3000c20))', 2.55, 0.7795, 1.11, 0.000379, '2025-11-15T05:44:02-05:00', 24]
# ['vRMV00nb', 'group_neutralize(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 5),densify(sta1_allc5))', 2.55, 0.7847, 1.12, 0.000387, '2025-11-15T05:36:10-05:00', 24]
# ['VkjoJoPY', 'group_neutralize(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 5),densify(subindustry))', 2.55, 0.7446, 1.17, 0.000424, '2025-11-15T05:23:22-05:00', 24]
# ['O0PvE8jY', 'group_neutralize(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 5),densify(sta1_allc5))', 2.55, 0.7847, 1.12, 0.000387, '2025-11-15T05:19:41-05:00', 24]
# ['P0aEq93K', 'group_zscore(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 5),densify(subindustry))', 2.54, 0.7552, 1.13, 0.000395, '2025-11-15T05:54:31-05:00', 24]
# ['j2RQlwAZ', 'group_zscore(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 5),densify(sta1_allc5))', 2.54, 0.7822, 1.12, 0.000386, '2025-11-15T05:49:17-05:00', 24]
# ['RRQLnKva', 'group_zscore(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 5),densify(sta1_allc10))', 2.54, 0.7797, 1.11, 0.000381, '2025-11-15T05:20:52-05:00', 24]
# ['vRMVaN6b', 'group_zscore(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 5),densify(sta2_top3000_fact4_c20))', 2.52, 0.7879, 1.08, 0.000367, '2025-11-15T05:44:22-05:00', 24]
# ['zq6zwjEG', 'group_zscore(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 5),densify(pv13_r2_min20_3000_sector))', 2.51, 0.7791, 1.12, 0.000395, '2025-11-15T05:49:12-05:00', 24]
# ['e7wJe0gl', 'group_zscore(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 5),densify(sta1_top3000c50))', 2.51, 0.7905, 1.06, 0.000355, '2025-11-15T05:43:58-05:00', 24]
# ['MPRA9e5n', 'group_zscore(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 5),densify(sta1_allc20))', 2.49, 0.7802, 1.08, 0.000373, '2025-11-15T05:45:44-05:00', 24]
# ['j2RQbeEE', 'group_neutralize(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 5),densify(sta2_top3000_fact4_c20))', 2.49, 0.7863, 1.06, 0.000363, '2025-11-15T05:19:42-05:00', 24]
# ['MPRAlWK9', 'group_neutralize(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 5),densify(sta2_top3000_fact3_c50))', 2.45, 0.7866, 1.02, 0.000347, '2025-11-15T05:47:50-05:00', 24]
# ['zq6zwMP8', 'group_zscore(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 5),densify(sta2_top3000_fact3_c50))', 2.35, 0.7917, 0.95, 0.000327, '2025-11-15T05:47:50-05:00', 24]
# ['889qqwJX', 'group_neutralize(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 5),densify(pv13_h_min2_3000_sector))', 2.29, 0.798, 0.96, 0.000354, '2025-11-15T05:34:44-05:00', 24]
# ['RRQLn6Ob', 'group_neutralize(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 5),densify(pv13_h_min2_3000_sector))', 2.29, 0.798, 0.96, 0.000354, '2025-11-15T05:19:41-05:00', 24]
# ['9q1Qgrl2', "group_neutralize(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 120),densify(bucket(rank(ts_std_dev(returns,20)),range = '0.1, 1, 0.1')))", 1.9, 0.0944, 1.21, 0.001067, '2025-11-15T05:44:02-05:00', 6]
# ['3qrWZj20', "group_neutralize(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 120),densify(bucket(group_rank(cap, sector),range='0.1, 1, 0.1')))", 1.9, 0.0918, 1.22, 0.001115, '2025-11-15T05:19:49-05:00', 6]
# ['zq6zaYrX', "group_neutralize(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 120),densify(bucket(rank(cap), range='0.1, 1, 0.1')))", 1.89, 0.0918, 1.2, 0.001107, '2025-11-15T05:38:32-05:00', 6]
# ['wpxVVYax', "group_zscore(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 120),densify(bucket(rank(ts_std_dev(returns,20)),range = '0.1, 1, 0.1')))", 1.89, 0.0935, 1.17, 0.001033, '2025-11-15T05:32:13-05:00', 6]
# ['P0aE9q6M', "group_zscore(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 120),densify(bucket(rank(ts_std_dev(returns,20)),range = '0.1, 1, 0.1')))", 1.89, 0.0935, 1.17, 0.001033, '2025-11-15T05:23:57-05:00', 6]
# ['pwrgoXNj', "group_zscore(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 120),densify(bucket(group_rank(cap, sector),range='0.1, 1, 0.1')))", 1.84, 0.09, 1.14, 0.001076, '2025-11-15T05:54:05-05:00', 6]
# ['gJOz78dv', "group_zscore(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 120),densify(bucket(rank(cap), range='0.1, 1, 0.1')))", 1.84, 0.09, 1.14, 0.001073, '2025-11-15T05:44:22-05:00', 6]
# ['580Voe2J', "group_neutralize(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 120),densify(bucket(rank(close*volume),range = '0.1, 1, 0.1')))", 1.76, 0.0946, 1.11, 0.001053, '2025-11-15T05:20:52-05:00', 6]
# ['3qrWYxJO', "group_zscore(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 120),densify(bucket(rank(close*volume),range = '0.1, 1, 0.1')))", 1.74, 0.0944, 1.09, 0.001038, '2025-11-15T05:49:11-05:00', 6]
# ['O0PvKQpb', "group_neutralize(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 120),densify(bucket(group_rank(assets, sector),range='0.1, 1, 0.1')))", 1.74, 0.0914, 1.09, 0.001083, '2025-11-15T05:41:24-05:00', 6]
# ['vRMVaNGb', 'group_neutralize(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 120),densify(sector))', 1.73, 0.0901, 1.09, 0.001109, '2025-11-15T05:44:22-05:00', 6]
# ['xA8aXkWb', 'group_zscore(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 120),densify(market))', 1.73, 0.0896, 1.09, 0.001112, '2025-11-15T05:44:03-05:00', 6]
# ['A1ZdMQ8g', 'group_neutralize(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 120),densify(market))', 1.73, 0.0902, 1.09, 0.001109, '2025-11-15T05:19:50-05:00', 6]
# ['vRMVxLnG', 'group_neutralize(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 120),densify(subindustry))', 1.72, 0.0878, 1.08, 0.001127, '2025-11-15T05:56:15-05:00', 6]
# ['vRMV3OKG', 'group_neutralize(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 120),densify(industry))', 1.72, 0.0896, 1.09, 0.001112, '2025-11-15T05:19:42-05:00', 6]
# ['E5WAX60R', 'group_zscore(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 120),densify(sector))', 1.71, 0.0887, 1.07, 0.00111, '2025-11-15T05:19:53-05:00', 6]
# ['leOZkqWl', 'group_zscore(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 120),densify(industry))', 1.68, 0.0839, 1.04, 0.001136, '2025-11-15T05:54:05-05:00', 6]
# ['9q1Q0Qwo', "group_zscore(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 120),densify(bucket(group_rank(assets, sector),range='0.1, 1, 0.1')))", 1.68, 0.0898, 1.03, 0.001049, '2025-11-15T05:23:21-05:00', 6]
# ['ZY3Lqpqx', 'group_neutralize(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 120),densify(pv13_r2_min20_3000_sector))', 1.61, 0.0922, 0.97, 0.000991, '2025-11-15T05:56:15-05:00', 6]
# ['WjQmnq7d', 'group_zscore(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 120),densify(subindustry))', 1.61, 0.0736, 0.95, 0.001194, '2025-11-15T05:54:05-05:00', 6]
# ['akZ3v3n9', "group_neutralize(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 120),densify(bucket(rank(assets),range='0.1, 1, 0.1')))", 1.6, 0.0939, 0.97, 0.000982, '2025-11-15T05:23:22-05:00', 6]
# ['0m3WvW7p', 'group_neutralize(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 120),densify(sta2_top3000_fact4_c10))', 1.57, 0.0913, 0.92, 0.00094, '2025-11-15T05:23:21-05:00', 6]
# ['YPKdGxOR', "group_zscore(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 120),densify(bucket(rank(assets),range='0.1, 1, 0.1')))", 1.56, 0.092, 0.93, 0.000958, '2025-11-15T05:19:50-05:00', 6]
# ['rKgmXEz9', 'group_zscore(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 120),densify(sta2_top3000_fact4_c10))', 1.53, 0.0902, 0.88, 0.000926, '2025-11-15T05:23:57-05:00', 6]
# ['O0Pvavxp', 'group_neutralize(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 120),densify(pv13_h_min2_3000_sector))', 1.53, 0.0986, 0.87, 0.000814, '2025-11-15T05:23:22-05:00', 6]
# ['3qrWZo3O', 'group_neutralize(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 120),densify(sta2_top3000_fact3_c50))', 1.52, 0.0944, 0.85, 0.000823, '2025-11-15T05:19:53-05:00', 6]
# ['WjQm6LMo', 'group_neutralize(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 120),densify(sta2_top3000_fact4_c20))', 1.52, 0.0923, 0.87, 0.000888, '2025-11-15T05:19:42-05:00', 6]
# ['JjELROrj', 'group_zscore(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 120),densify(pv13_r2_min20_3000_sector))', 1.5, 0.0847, 0.86, 0.000975, '2025-11-15T05:44:03-05:00', 6]
# ['2rzkQ0l5', 'group_neutralize(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 120),densify(sta1_allc20))', 1.46, 0.0927, 0.82, 0.000856, '2025-11-15T05:54:05-05:00', 6]
# ['leOZJpVN', 'group_zscore(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 120),densify(sta2_top3000_fact4_c20))', 1.46, 0.0906, 0.82, 0.000863, '2025-11-15T05:41:24-05:00', 6]
# ['xA8a96NJ', "group_zscore(group_zscore(-inverse(winsorize(ts_backfill(fnd6_newqv1300_stkcoq, 120), std=4)),densify(bucket(group_rank(cap,sector),range='0,1,0.1'))),densify(bucket(rank(ts_std_dev(returns,20)),range = '0.1, 1, 0.1')))", 1.41, 0.1314, 1.0, 0.001016, '2025-11-15T05:54:05-05:00', 6]
# 100
# count: 76
# 三阶表达式数量:240

# %% [markdown]
# ### Simulate Third Order

# %%
# Simulate third order
th_pools = load_task_pool(th_alpha_list, 6, 6)
multi_simulate(th_pools, 'SUBINDUSTRY', 'USA', 'TOP3000', 0)
# Out:
# b'{"user":{"id":"HS29282"},"token":{"expiry":14400.0},"permissions":["BEFORE_AND_AFTER_PERFORMANCE_V2","BRAIN_LABS","BRAIN_LABS_JUPYTER_LAB","CONSULTANT","MULTI_SIMULATION","PROD_ALPHAS","REFERRAL","SUPER_ALPHA","VISUALIZATION","WORKDAY"]}'
# pool 0 task 5 post done
# pool 0 task 5 simulate done
# pool 1 task 5 post done
# pool 1 task 5 simulate done
# pool 2 task 5 post done
# pool 2 task 5 simulate done
# pool 3 task 5 post done
# pool 3 task 5 simulate done
# pool 4 task 5 post done
# pool 4 task 5 simulate done
# pool 5 task 5 post done
# pool 5 task 5 simulate done
# pool 6 task 3 post done
# pool 6 task 3 simulate done
# Simulate done

# %% [markdown]
# ## 11, 获取可提交的Alpha
#
# <div style="margin-left: 20px;">
# 1, 拉取sharpe,fitness达到提交要求的alpha
# </div>
#
# <div style="margin-left: 20px;">
# 2, Check Submission：检查其他Test是否达到要求
# </div>
#
# <div style="margin-left: 20px;">
# 2, view_alphas 对可以提交的alpha进行排序
# </div>

# %%
# 1.58 sharpe, 1 fitness, "submit"参数
th_tracker = get_alphas("11-14", "11-16", 1.58, 1, "USA", 200, "submit")
# Out:
# b'{"user":{"id":"HS29282"},"token":{"expiry":14400.0},"permissions":["BEFORE_AND_AFTER_PERFORMANCE_V2","BRAIN_LABS","BRAIN_LABS_JUPYTER_LAB","CONSULTANT","MULTI_SIMULATION","PROD_ALPHAS","REFERRAL","SUPER_ALPHA","VISUALIZATION","WORKDAY"]}'
# 0
# ['qMrZelVP', "group_neutralize(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 5),densify(bucket(rank(ts_std_dev(returns,20)),range = '0.1, 1, 0.1')))", 2.69, 0.7832, 1.21, 0.000407, '2025-11-15T05:44:03-05:00', 24]
# ['E5WAAkOP', "group_neutralize(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 5),densify(bucket(group_rank(cap, sector),range='0.1, 1, 0.1')))", 2.69, 0.7821, 1.21, 0.000405, '2025-11-15T05:31:13-05:00', 24]
# ['rKgmvRkj', "group_neutralize(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 5),densify(bucket(group_rank(cap, sector),range='0.1, 1, 0.1')))", 2.69, 0.7821, 1.21, 0.000405, '2025-11-15T05:19:52-05:00', 24]
# ['889qkoOm', "group_neutralize(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 5),densify(bucket(rank(cap), range='0.1, 1, 0.1')))", 2.68, 0.7822, 1.21, 0.000406, '2025-11-15T05:47:50-05:00', 24]
# ['wpxVXaGY', "group_zscore(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 5),densify(bucket(rank(cap), range='0.1, 1, 0.1')))", 2.68, 0.7789, 1.21, 0.000406, '2025-11-15T05:44:22-05:00', 24]
# ['Vkjoq97J', "group_zscore(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 5),densify(bucket(group_rank(cap, sector),range='0.1, 1, 0.1')))", 2.67, 0.7794, 1.2, 0.000404, '2025-11-15T05:54:05-05:00', 24]
# ['qMrZkbrE', "group_neutralize(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 5),densify(bucket(group_rank(assets, sector),range='0.1, 1, 0.1')))", 2.67, 0.7823, 1.2, 0.000403, '2025-11-15T05:48:32-05:00', 24]
# ['kqr5RVgz', 'group_zscore(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 5),densify(market))', 2.67, 0.7789, 1.21, 0.000411, '2025-11-15T05:38:32-05:00', 24]
# ['6XVb3OwJ', "group_zscore(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 5),densify(bucket(group_rank(assets, sector),range='0.1, 1, 0.1')))", 2.66, 0.7796, 1.19, 0.000401, '2025-11-15T05:54:30-05:00', 24]
# ['d5VwAo6j', "group_zscore(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 5),densify(bucket(rank(ts_std_dev(returns,20)),range = '0.1, 1, 0.1')))", 2.66, 0.7802, 1.2, 0.000406, '2025-11-15T05:20:52-05:00', 24]
# ['JjELYwvE', 'group_neutralize(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 5),densify(market))', 2.65, 0.7799, 1.2, 0.000408, '2025-11-15T05:54:05-05:00', 24]
# ['xA8aMq7p', 'group_neutralize(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 5),densify(pv13_r2_min20_3000_sector))', 2.65, 0.772, 1.21, 0.000417, '2025-11-15T05:35:24-05:00', 24]
# ['LLaxAr3L', 'group_neutralize(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 5),densify(pv13_r2_min20_3000_sector))', 2.65, 0.772, 1.21, 0.000417, '2025-11-15T05:20:52-05:00', 24]
# ['RRQLqWp0', 'group_neutralize(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 5),densify(sta1_top3000c50))', 2.62, 0.7885, 1.13, 0.000372, '2025-11-15T05:54:30-05:00', 24]
# ['E5WAY7eP', 'group_neutralize(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 5),densify(industry))', 2.62, 0.7655, 1.19, 0.000414, '2025-11-15T05:54:05-05:00', 24]
# ['om5ewp9n', 'group_neutralize(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 5),densify(sta1_top3000c20))', 2.62, 0.7853, 1.15, 0.000387, '2025-11-15T05:47:50-05:00', 24]
# ['QPkdeAOg', 'group_neutralize(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 5),densify(sector))', 2.62, 0.7771, 1.18, 0.000405, '2025-11-15T05:40:18-05:00', 24]
# ['2rzkEEQ5', 'group_zscore(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 5),densify(sta2_top3000_fact4_c10))', 2.62, 0.785, 1.15, 0.000385, '2025-11-15T05:36:10-05:00', 24]
# ['QPkdLK8w', "group_neutralize(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 5),densify(bucket(rank(close*volume),range = '0.1, 1, 0.1')))", 2.62, 0.7841, 1.17, 0.0004, '2025-11-15T05:19:41-05:00', 24]
# ['d5VwA1rg', 'group_zscore(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 5),densify(sta2_top3000_fact4_c10))', 2.62, 0.785, 1.15, 0.000385, '2025-11-15T05:19:41-05:00', 24]
# ['A1ZdKdPR', 'group_zscore(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 5),densify(sector))', 2.6, 0.7735, 1.17, 0.000404, '2025-11-15T05:23:22-05:00', 24]
# ['kqr5RM8z', 'group_zscore(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 5),densify(industry))', 2.58, 0.7605, 1.16, 0.000405, '2025-11-15T05:40:18-05:00', 24]
# ['WjQmkPeo', "group_zscore(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 5),densify(bucket(rank(close*volume),range = '0.1, 1, 0.1')))", 2.58, 0.7814, 1.15, 0.000394, '2025-11-15T05:38:32-05:00', 24]
# ['gJOz7Mq0', 'group_neutralize(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 5),densify(sta1_allc20))', 2.57, 0.7851, 1.13, 0.000385, '2025-11-15T05:43:58-05:00', 24]
# ['O0PvEJgq', 'group_neutralize(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 5),densify(sta1_allc10))', 2.57, 0.7843, 1.13, 0.000386, '2025-11-15T05:19:49-05:00', 24]
# ['vRMV31xr', 'group_neutralize(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 5),densify(sta2_top3000_fact4_c10))', 2.56, 0.7852, 1.11, 0.000376, '2025-11-15T05:19:53-05:00', 24]
# ['xA8a01oN', "group_neutralize(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 5),densify(bucket(rank(assets),range='0.1, 1, 0.1')))", 2.56, 0.7878, 1.14, 0.000396, '2025-11-15T05:19:49-05:00', 24]
# ['WjQm6LJP', "group_zscore(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 5),densify(bucket(rank(assets),range='0.1, 1, 0.1')))", 2.56, 0.7844, 1.14, 0.000394, '2025-11-15T05:19:49-05:00', 24]
# ['mLRkebKW', 'group_zscore(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 5),densify(sta1_top3000c20))', 2.55, 0.7795, 1.11, 0.000379, '2025-11-15T05:44:02-05:00', 24]
# ['vRMV00nb', 'group_neutralize(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 5),densify(sta1_allc5))', 2.55, 0.7847, 1.12, 0.000387, '2025-11-15T05:36:10-05:00', 24]
# ['VkjoJoPY', 'group_neutralize(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 5),densify(subindustry))', 2.55, 0.7446, 1.17, 0.000424, '2025-11-15T05:23:22-05:00', 24]
# ['O0PvE8jY', 'group_neutralize(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 5),densify(sta1_allc5))', 2.55, 0.7847, 1.12, 0.000387, '2025-11-15T05:19:41-05:00', 24]
# ['P0aEq93K', 'group_zscore(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 5),densify(subindustry))', 2.54, 0.7552, 1.13, 0.000395, '2025-11-15T05:54:31-05:00', 24]
# ['j2RQlwAZ', 'group_zscore(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 5),densify(sta1_allc5))', 2.54, 0.7822, 1.12, 0.000386, '2025-11-15T05:49:17-05:00', 24]
# ['RRQLnKva', 'group_zscore(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 5),densify(sta1_allc10))', 2.54, 0.7797, 1.11, 0.000381, '2025-11-15T05:20:52-05:00', 24]
# ['vRMVaN6b', 'group_zscore(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 5),densify(sta2_top3000_fact4_c20))', 2.52, 0.7879, 1.08, 0.000367, '2025-11-15T05:44:22-05:00', 24]
# ['zq6zwjEG', 'group_zscore(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 5),densify(pv13_r2_min20_3000_sector))', 2.51, 0.7791, 1.12, 0.000395, '2025-11-15T05:49:12-05:00', 24]
# ['e7wJe0gl', 'group_zscore(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 5),densify(sta1_top3000c50))', 2.51, 0.7905, 1.06, 0.000355, '2025-11-15T05:43:58-05:00', 24]
# ['MPRA9e5n', 'group_zscore(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 5),densify(sta1_allc20))', 2.49, 0.7802, 1.08, 0.000373, '2025-11-15T05:45:44-05:00', 24]
# ['j2RQbeEE', 'group_neutralize(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 5),densify(sta2_top3000_fact4_c20))', 2.49, 0.7863, 1.06, 0.000363, '2025-11-15T05:19:42-05:00', 24]
# ['MPRAlWK9', 'group_neutralize(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 5),densify(sta2_top3000_fact3_c50))', 2.45, 0.7866, 1.02, 0.000347, '2025-11-15T05:47:50-05:00', 24]
# ['zq6zYgmR', "trade_when(ts_std_dev(returns, 5) > ts_std_dev(returns, 20), group_zscore(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 5),densify(bucket(rank(cap), range='0.1, 1, 0.1'))), abs(returns) > 0.1)", 2.24, 0.5156, 1.03, 0.000426, '2025-11-15T07:17:39-05:00', 96]
# ['3qrW91kg', "trade_when(ts_std_dev(returns, 5) > ts_std_dev(returns, 20), group_neutralize(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 5),densify(bucket(rank(cap), range='0.1, 1, 0.1'))), abs(returns) > 0.1)", 2.22, 0.5191, 1.02, 0.000425, '2025-11-15T07:17:43-05:00', 96]
# ['WjQmV0YQ', "trade_when(ts_std_dev(returns, 5) > ts_std_dev(returns, 20), group_neutralize(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 5),densify(bucket(rank(ts_std_dev(returns,20)),range = '0.1, 1, 0.1'))), abs(returns) > 0.1)", 2.2, 0.5201, 1.01, 0.000424, '2025-11-15T06:59:26-05:00', 96]
# ['rKgmlkQa', "trade_when(ts_std_dev(returns, 5) > ts_std_dev(returns, 20), group_neutralize(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 5),densify(bucket(group_rank(cap, sector),range='0.1, 1, 0.1'))), abs(returns) > 0.1)", 2.19, 0.5192, 1.01, 0.000422, '2025-11-15T06:49:49-05:00', 96]
# ['npRb8bxw', "trade_when(group_rank(ts_std_dev(returns,60), sector) > 0.7, group_neutralize(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 5),densify(bucket(group_rank(cap, sector),range='0.1, 1, 0.1'))), -1)", 1.96, 0.4046, 1.13, 0.00067, '2025-11-15T06:55:39-05:00', 96]
# ['gJOzMRRe', "trade_when(group_rank(ts_std_dev(returns,60), sector) > 0.7, group_neutralize(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 5),densify(bucket(group_rank(cap, sector),range='0.1, 1, 0.1'))), -1)", 1.96, 0.4046, 1.13, 0.00067, '2025-11-15T06:50:46-05:00', 96]
# ['889qQ7nv', "trade_when(group_rank(ts_std_dev(returns,60), sector) > 0.7, group_neutralize(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 5),densify(bucket(group_rank(cap, sector),range='0.1, 1, 0.1'))), abs(returns) > 0.1)", 1.91, 0.5463, 1.08, 0.000643, '2025-11-15T06:50:15-05:00', 96]
# ['9q1Qgrl2', "group_neutralize(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 120),densify(bucket(rank(ts_std_dev(returns,20)),range = '0.1, 1, 0.1')))", 1.9, 0.0944, 1.21, 0.001067, '2025-11-15T05:44:02-05:00', 6]
# ['3qrWZj20', "group_neutralize(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 120),densify(bucket(group_rank(cap, sector),range='0.1, 1, 0.1')))", 1.9, 0.0918, 1.22, 0.001115, '2025-11-15T05:19:49-05:00', 6]
# ['zq6zaYrX', "group_neutralize(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 120),densify(bucket(rank(cap), range='0.1, 1, 0.1')))", 1.89, 0.0918, 1.2, 0.001107, '2025-11-15T05:38:32-05:00', 6]
# ['wpxVVYax', "group_zscore(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 120),densify(bucket(rank(ts_std_dev(returns,20)),range = '0.1, 1, 0.1')))", 1.89, 0.0935, 1.17, 0.001033, '2025-11-15T05:32:13-05:00', 6]
# ['P0aE9q6M', "group_zscore(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 120),densify(bucket(rank(ts_std_dev(returns,20)),range = '0.1, 1, 0.1')))", 1.89, 0.0935, 1.17, 0.001033, '2025-11-15T05:23:57-05:00', 6]
# ['RRQLVRg1', "trade_when(group_rank(ts_std_dev(returns,60), sector) > 0.7, group_neutralize(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 5),densify(bucket(rank(cap), range='0.1, 1, 0.1'))), abs(returns) > 0.1)", 1.88, 0.5461, 1.06, 0.000642, '2025-11-15T07:12:56-05:00', 96]
# ['GrAvL790', "trade_when(group_rank(ts_std_dev(returns,60), sector) > 0.7, group_neutralize(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 5),densify(bucket(rank(cap), range='0.1, 1, 0.1'))), -1)", 1.88, 0.4044, 1.07, 0.000652, '2025-11-15T06:53:40-05:00', 96]
# ['RRQLV9zj', "trade_when(group_rank(ts_std_dev(returns,60), sector) > 0.7, group_zscore(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 5),densify(bucket(rank(cap), range='0.1, 1, 0.1'))), abs(returns) > 0.1)", 1.86, 0.5416, 1.05, 0.000639, '2025-11-15T07:17:43-05:00', 96]
# ['1Yb5w69m', "trade_when(group_rank(ts_std_dev(returns,60), sector) > 0.7, group_zscore(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 5),densify(bucket(rank(cap), range='0.1, 1, 0.1'))), -1)", 1.86, 0.3994, 1.06, 0.000652, '2025-11-15T07:08:03-05:00', 96]
# ['pwrgoXNj', "group_zscore(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 120),densify(bucket(group_rank(cap, sector),range='0.1, 1, 0.1')))", 1.84, 0.09, 1.14, 0.001076, '2025-11-15T05:54:05-05:00', 6]
# ['gJOz78dv', "group_zscore(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 120),densify(bucket(rank(cap), range='0.1, 1, 0.1')))", 1.84, 0.09, 1.14, 0.001073, '2025-11-15T05:44:22-05:00', 6]
# ['RRQL1wOn', "trade_when(group_rank(ts_std_dev(returns,60), sector) > 0.7, group_neutralize(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 5),densify(bucket(rank(ts_std_dev(returns,20)),range = '0.1, 1, 0.1'))), abs(returns) > 0.1)", 1.83, 0.5484, 1.02, 0.000625, '2025-11-15T07:00:00-05:00', 96]
# ['580Voe2J', "group_neutralize(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 120),densify(bucket(rank(close*volume),range = '0.1, 1, 0.1')))", 1.76, 0.0946, 1.11, 0.001053, '2025-11-15T05:20:52-05:00', 6]
# ['3qrWYxJO', "group_zscore(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 120),densify(bucket(rank(close*volume),range = '0.1, 1, 0.1')))", 1.74, 0.0944, 1.09, 0.001038, '2025-11-15T05:49:11-05:00', 6]
# ['O0PvKQpb', "group_neutralize(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 120),densify(bucket(group_rank(assets, sector),range='0.1, 1, 0.1')))", 1.74, 0.0914, 1.09, 0.001083, '2025-11-15T05:41:24-05:00', 6]
# ['vRMVaNGb', 'group_neutralize(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 120),densify(sector))', 1.73, 0.0901, 1.09, 0.001109, '2025-11-15T05:44:22-05:00', 6]
# ['xA8aXkWb', 'group_zscore(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 120),densify(market))', 1.73, 0.0896, 1.09, 0.001112, '2025-11-15T05:44:03-05:00', 6]
# ['A1ZdMQ8g', 'group_neutralize(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 120),densify(market))', 1.73, 0.0902, 1.09, 0.001109, '2025-11-15T05:19:50-05:00', 6]
# ['vRMVxLnG', 'group_neutralize(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 120),densify(subindustry))', 1.72, 0.0878, 1.08, 0.001127, '2025-11-15T05:56:15-05:00', 6]
# ['vRMV3OKG', 'group_neutralize(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 120),densify(industry))', 1.72, 0.0896, 1.09, 0.001112, '2025-11-15T05:19:42-05:00', 6]
# ['E5WAX60R', 'group_zscore(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 120),densify(sector))', 1.71, 0.0887, 1.07, 0.00111, '2025-11-15T05:19:53-05:00', 6]
# ['leOZkqWl', 'group_zscore(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 120),densify(industry))', 1.68, 0.0839, 1.04, 0.001136, '2025-11-15T05:54:05-05:00', 6]
# ['9q1Q0Qwo', "group_zscore(-ts_zscore(winsorize(ts_backfill(vec_avg(anl4_mark), 120), std=4), 120),densify(bucket(group_rank(assets, sector),range='0.1, 1, 0.1')))", 1.68, 0.0898, 1.03, 0.001049, '2025-11-15T05:23:21-05:00', 6]
# 100
# count: 72

# %%
## 将get的alpha的id取出至stone_bag，用api check submission
stone_bag = []
for alpha in th_tracker:
    stone_bag.append(alpha[0])
print(len(stone_bag))
gold_bag = []
check_submission(stone_bag, gold_bag, 0)
# Out:
# 71
# b'{"user":{"id":"HS29282"},"token":{"expiry":14400.0},"permissions":["BEFORE_AND_AFTER_PERFORMANCE_V2","BRAIN_LABS","BRAIN_LABS_JUPYTER_LAB","CONSULTANT","MULTI_SIMULATION","PROD_ALPHAS","REFERRAL","SUPER_ALPHA","VISUALIZATION","WORKDAY"]}'
# 0
# b'{"user":{"id":"HS29282"},"token":{"expiry":14400.0},"permissions":["BEFORE_AND_AFTER_PERFORMANCE_V2","BRAIN_LABS","BRAIN_LABS_JUPYTER_LAB","CONSULTANT","MULTI_SIMULATION","PROD_ALPHAS","REFERRAL","SUPER_ALPHA","VISUALIZATION","WORKDAY"]}'
# 5
# 10
# 15
# 20
# 25
# 30
# 35
# 40
# 45
# 50
# 55
# 60
# 65
# 70
# []
# []

# %%
# 打印可提交的alpha信息并按sharpe排序，在网页上找到alpha手动提交
view_alphas(gold_bag)
# Out:
# b'{"user":{"id":"HS29282"},"token":{"expiry":14400.0},"permissions":["BEFORE_AND_AFTER_PERFORMANCE_V2","BRAIN_LABS","BRAIN_LABS_JUPYTER_LAB","CONSULTANT","MULTI_SIMULATION","PROD_ALPHAS","REFERRAL","SUPER_ALPHA","VISUALIZATION","WORKDAY"]}'

# %% [markdown]
# ## 12, 微调可以提交的alpha
#
# <div style="margin-left: 20px;">
# 1, 得到更好的表现
# </div>
# <div style="margin-left: 40px;">
# 调整中性化，操作符参数，Decay
# </div>
#
# <div style="margin-left: 20px;">
# 2, Alpha质量评估
# </div>
#
# <div style="margin-left: 40px;">
# performance comparison，turnover，margin
# </div>
#
# <div style="margin-left: 20px;">
# 3, 鲁棒性评估，防止过拟合
# </div>
#
# <div style="margin-left: 40px;">
# 更改中性化，Rank，Binary Test...
# </div>

# %% [markdown]
# ### Appendix

# %%
# 模板构建Factory实例

def template_factory(sent_fields, option_fields):
    alpha_list = []
    for sent_field in sent_fields:
        for opt_field in option_fields:
            alpha_list.append("log(1+sigmoid(ts_zscore(%s,30))*sigmoid(ts_zscore(%s,30))"%(sent_field, opt_field))
    return alpha_list 

opt_df = get_datafields(s, dataset_id = 'option8', region='USA', universe='TOP3000', delay=1)
opt_fields = opt_df[opt_df['type'] == "MATRIX"]["id"].tolist()
print(opt_fields)

sent_df = get_datafields(s, dataset_id = 'sentiment1', region='USA', universe='TOP3000', delay=1)
sent_fields = sent_df[sent_df['type'] == "MATRIX"]["id"].tolist()
print(sent_fields)

alpha_list = template_factory(sent_fields, opt_fields)
print(alpha_list)
